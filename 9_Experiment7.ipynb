# %% [markdown]
# <a href="https://colab.research.google.com/github/JITHIN-ANTONY-JOSEPH/ERP_11358080/blob/main/9_Experiment7.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# ### Input : Recipe Instructions
# ### Model : Word2Vec(Text) + Node2Vec(Graph) + Neural Networks(Model) with CROSS VALIDATION

# %% [markdown]
# ### Mounting to connect to Google Drive

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %% [markdown]
# ### Install required libraries

# %%
# !pip install node2vec
# Out:
# Collecting node2vec
#   Downloading node2vec-0.5.0-py3-none-any.whl.metadata (849 bytes)
# Requirement already satisfied: gensim<5.0.0,>=4.3.0 in /usr/local/lib/python3.10/dist-packages (from node2vec) (4.3.3)
# Requirement already satisfied: joblib<2.0.0,>=1.4.0 in /usr/local/lib/python3.10/dist-packages (from node2vec) (1.4.2)
# Requirement already satisfied: networkx<4.0.0,>=3.1.0 in /usr/local/lib/python3.10/dist-packages (from node2vec) (3.3)
# Requirement already satisfied: numpy<2.0.0,>=1.24.0 in /usr/local/lib/python3.10/dist-packages (from node2vec) (1.26.4)
# Requirement already satisfied: tqdm<5.0.0,>=4.66.1 in /usr/local/lib/python3.10/dist-packages (from node2vec) (4.66.5)
# Requirement already satisfied: scipy<1.14.0,>=1.7.0 in /usr/local/lib/python3.10/dist-packages (from gensim<5.0.0,>=4.3.0->node2vec) (1.13.1)
# Requirement already satisfied: smart-open>=1.8.1 in /usr/local/lib/python3.10/dist-packages (from gensim<5.0.0,>=4.3.0->node2vec) (7.0.4)
# Requirement already satisfied: wrapt in /usr/local/lib/python3.10/dist-packages (from smart-open>=1.8.1->gensim<5.0.0,>=4.3.0->node2vec) (1.16.0)
# Downloading node2vec-0.5.0-py3-none-any.whl (7.2 kB)
# Installing collected packages: node2vec
# Successfully installed node2vec-0.5.0

# %% [markdown]
# ### Importing required libraries , loading datasets and pre-processing, final_model and evaluation

# %%
import numpy as np
import pandas as pd
import json
import re
import jellyfish
from gensim.models import Word2Vec
from concurrent.futures import ProcessPoolExecutor
import torch
import torch.nn as nn
import torch.optim as optim
import torch.nn.functional as F
from sklearn.metrics.pairwise import cosine_similarity
from sklearn.model_selection import KFold
import networkx as nx

# Load datasets
flavorgraph_df = pd.read_csv('/content/drive/My Drive/ERP/Dataset/nodes_191120.csv')  # Adjust the path as needed , this is the path to my personal Google Drive
with open('/content/drive/My Drive/ERP/modified_Processed_Layer1.json', 'r') as file:
    recipe1m_data = [json.loads(line) for line in file]
recipe1m_df = pd.DataFrame(recipe1m_data)
substitution_pairs_df = pd.read_csv('/content/drive/My Drive/ERP/Recipe1MSubs_full.csv') # Adjust the path as needed , this is the path to my personal Google Drive

# Merge the datasets based on recipe_id (substitution_pairs_df) and id (recipe1m_df)
merged_df = pd.merge(recipe1m_df, substitution_pairs_df, left_on='id', right_on='recipe_id')

# Example ingredient list for NER-like extraction (replace with your own comprehensive list or use NER model)
ingredient_list = set(flavorgraph_df[flavorgraph_df['node_type'] == 'ingredient']['name'].dropna().unique())

# Function to extract ingredients from instructions
def extract_ingredients_from_instructions(instructions, ingredient_list):
    extracted_ingredients = []
    for instruction in instructions:
        words = instruction.split()
        for word in words:
            if word in ingredient_list:
                extracted_ingredients.append(word)
    return extracted_ingredients

# Apply the extraction function
recipe1m_df['extracted_ingredients'] = recipe1m_df['processed_instructions'].apply(
    lambda instructions: extract_ingredients_from_instructions(instructions, ingredient_list) if isinstance(instructions, list) else []
)

# Prepare sentences for training
sentences = recipe1m_df['extracted_ingredients'].tolist()

# Add substitution contexts to sentences
for _, row in substitution_pairs_df.iterrows():
    ingredient1 = row['ingredient1']
    ingredient2 = row['ingredient2']
    sentences.append([ingredient1, ingredient2])

# Train the Word2Vec model
model = Word2Vec(sentences, vector_size=100, window=5, min_count=1, workers=8)  # Increase 'workers' to utilize more CPU cores

# Load the knowledge graph
flavor_graph = nx.read_graphml('/content/drive/My Drive/ERP/knowledge_graph.graphml') # Adjust the path as needed , this is the path to my personal Google Drive

# Filter the graph for ingredient nodes only
def filter_ingredient_nodes(node, attr):
    return node if attr['node_type'] == 'ingredient' else None

ingredient_nodes = [node for node, attr in flavor_graph.nodes(data=True) if filter_ingredient_nodes(node, attr)]
flavor_graph = flavor_graph.subgraph(ingredient_nodes)

# Load the pre-generated Node2Vec model
graph_model = Word2Vec.load('/content/drive/My Drive/ERP/node2vec_model_actual.model') # Adjust the path as needed , this is the path to my personal Google Drive
graph_embeddings = {str(node): graph_model.wv[str(node)] for node in flavor_graph.nodes()}

# Function to combine text and graph embeddings
def get_combined_embedding(ingredient, text_embeddings, graph_embeddings):
    # Check if the ingredient is in the text embeddings
    if ingredient in text_embeddings:
        text_embedding = text_embeddings[ingredient]
    else:
        text_embedding = np.zeros(100)

    # Check if the ingredient is in the graph embeddings
    if ingredient in graph_embeddings:
        graph_embedding = graph_embeddings[ingredient]
    else:
        graph_embedding = np.zeros(100)

    # Combine text and graph embeddings
    combined_embedding = np.concatenate((text_embedding, graph_embedding))
    return combined_embedding

# Define the neural network
class CombinedNN(nn.Module):
    def __init__(self, input_dim, output_dim):
        super(CombinedNN, self).__init__()
        self.fc1 = nn.Linear(input_dim, 128)
        self.fc2 = nn.Linear(128, output_dim)
        self.dropout = nn.Dropout(0.5)

    def forward(self, x):
        x = F.relu(self.fc1(x))
        x = self.dropout(x)
        x = self.fc2(x)
        return x

# Function to find the top N most similar ingredients based on cosine similarity
def find_top_similar_ingredients(predicted_embedding, combined_embeddings, top_n=10):
    similarities = {}
    for ingredient, embedding in combined_embeddings.items():
        similarity = cosine_similarity(predicted_embedding.reshape(1, -1), embedding.reshape(1, -1))[0][0]
        similarities[ingredient] = similarity
    sorted_ingredients = sorted(similarities.items(), key=lambda item: item[1], reverse=True)
    return [ingredient for ingredient, similarity in sorted_ingredients[:top_n]]

# Function to calculate metrics with Jaro-Winkler similarity threshold
def calculate_metrics(predictions, ground_truths, combined_embeddings, top_n=10, threshold=0.8):
    mrr, hit_1, hit_3, hit_10 = 0.0, 0.0, 0.0, 0.0
    total = len(ground_truths)

    for pred, gt in zip(predictions, ground_truths):
        top_similar = find_top_similar_ingredients(pred, combined_embeddings, top_n=top_n)
        for rank, candidate in enumerate(top_similar, start=1):
            sim = jellyfish.jaro_winkler_similarity(gt, candidate)
            if sim >= threshold:
                mrr += 1.0 / rank
                if rank == 1:
                    hit_1 += 1.0
                if rank <= 3:
                    hit_3 += 1.0
                if rank <= 10:
                    hit_10 += 1.0
                break

    mrr /= total
    hit_1 /= total
    hit_3 /= total
    hit_10 /= total
    return mrr, hit_1, hit_3, hit_10

# Cross-validation setup
kf = KFold(n_splits=5)

# To store results across folds
all_mrr, all_hit_1, all_hit_3, all_hit_10 = [], [], [], []

for fold, (train_index, val_index) in enumerate(kf.split(substitution_pairs_df), 1):
    print(f"\nStarting Fold {fold}...")

    # Split data
    train_df, val_df = substitution_pairs_df.iloc[train_index], substitution_pairs_df.iloc[val_index]

    # (Re-initialize your model here)
    nn_model = CombinedNN(input_dim=200, output_dim=200)
    criterion = nn.MSELoss()
    optimizer = optim.Adam(nn_model.parameters(), lr=0.001)

    # Prepare train data and labels
    train_data = []
    train_labels = []
    for _, row in train_df.iterrows():
        ing1 = row['ingredient1']
        ing2 = row['ingredient2']
        combined_embedding1 = get_combined_embedding(ing1, model.wv, graph_embeddings)
        combined_embedding2 = get_combined_embedding(ing2, model.wv, graph_embeddings)
        train_data.append(combined_embedding1)
        train_labels.append(combined_embedding2)

    train_data = torch.tensor(train_data, dtype=torch.float32)
    train_labels = torch.tensor(train_labels, dtype=torch.float32)

    # Training loop
    for epoch in range(300):
        nn_model.train()
        optimizer.zero_grad()
        outputs = nn_model(train_data)
        loss = criterion(outputs, train_labels)
        loss.backward()
        optimizer.step()

        # Print loss for every epoch
        print(f"Fold {fold} | Epoch {epoch+1} | Loss: {loss.item():.4f}")

    # Prepare validation data for the first 500 entries
    val_data = []
    val_labels = []

    for _, row in val_df.iterrows():
        if len(val_data) >= 500:
            break
        ing1 = row['ingredient1']
        combined_embedding = get_combined_embedding(ing1, model.wv, graph_embeddings)

        val_data.append(combined_embedding)
        val_labels.append(row['ingredient2'])

    val_data = np.array(val_data)
    val_data = torch.tensor(val_data, dtype=torch.float32)
    val_predictions = nn_model(val_data).detach().numpy()

    # Calculate metrics for this fold
    combined_embeddings = {ingredient: get_combined_embedding(ingredient, model.wv, graph_embeddings) for ingredient in model.wv.index_to_key}
    mrr, hit_1, hit_3, hit_10 = calculate_metrics(val_predictions, val_labels, combined_embeddings)

    all_mrr.append(mrr)
    all_hit_1.append(hit_1)
    all_hit_3.append(hit_3)
    all_hit_10.append(hit_10)

# Compute the average metrics across all folds
avg_mrr = np.mean(all_mrr)
avg_hit_1 = np.mean(all_hit_1)
avg_hit_3 = np.mean(all_hit_3)
avg_hit_10 = np.mean(all_hit_10)

print(f"\nFinal Results after Cross-Validation:")
print(f"Average MRR: {avg_mrr:.4f}, Average Hit@1: {avg_hit_1:.4f}, Average Hit@3: {avg_hit_3:.4f}, Average Hit@10: {avg_hit_10:.4f}")
# Out:
# Starting Fold 1...
# Fold 1 | Epoch 1 | Loss: 0.8221
# Fold 1 | Epoch 2 | Loss: 0.8026
# Fold 1 | Epoch 3 | Loss: 0.7873
# Fold 1 | Epoch 4 | Loss: 0.7747
# Fold 1 | Epoch 5 | Loss: 0.7644
# Fold 1 | Epoch 6 | Loss: 0.7558
# Fold 1 | Epoch 7 | Loss: 0.7487
# Fold 1 | Epoch 8 | Loss: 0.7430
# Fold 1 | Epoch 9 | Loss: 0.7375
# Fold 1 | Epoch 10 | Loss: 0.7333
# Fold 1 | Epoch 11 | Loss: 0.7292
# Fold 1 | Epoch 12 | Loss: 0.7256
# Fold 1 | Epoch 13 | Loss: 0.7221
# Fold 1 | Epoch 14 | Loss: 0.7189
# Fold 1 | Epoch 15 | Loss: 0.7160
# Fold 1 | Epoch 16 | Loss: 0.7130
# Fold 1 | Epoch 17 | Loss: 0.7101
# Fold 1 | Epoch 18 | Loss: 0.7079
# Fold 1 | Epoch 19 | Loss: 0.7055
# Fold 1 | Epoch 20 | Loss: 0.7034
# Fold 1 | Epoch 21 | Loss: 0.7011
# Fold 1 | Epoch 22 | Loss: 0.6990
# Fold 1 | Epoch 23 | Loss: 0.6972
# Fold 1 | Epoch 24 | Loss: 0.6952
# Fold 1 | Epoch 25 | Loss: 0.6932
# Fold 1 | Epoch 26 | Loss: 0.6914
# Fold 1 | Epoch 27 | Loss: 0.6897
# Fold 1 | Epoch 28 | Loss: 0.6879
# Fold 1 | Epoch 29 | Loss: 0.6869
# Fold 1 | Epoch 30 | Loss: 0.6857
# Fold 1 | Epoch 31 | Loss: 0.6838
# Fold 1 | Epoch 32 | Loss: 0.6828
# Fold 1 | Epoch 33 | Loss: 0.6814
# Fold 1 | Epoch 34 | Loss: 0.6804
# Fold 1 | Epoch 35 | Loss: 0.6790
# Fold 1 | Epoch 36 | Loss: 0.6779
# Fold 1 | Epoch 37 | Loss: 0.6764
# Fold 1 | Epoch 38 | Loss: 0.6757
# Fold 1 | Epoch 39 | Loss: 0.6743
# Fold 1 | Epoch 40 | Loss: 0.6734
# Fold 1 | Epoch 41 | Loss: 0.6725
# Fold 1 | Epoch 42 | Loss: 0.6718
# Fold 1 | Epoch 43 | Loss: 0.6703
# Fold 1 | Epoch 44 | Loss: 0.6696
# Fold 1 | Epoch 45 | Loss: 0.6691
# Fold 1 | Epoch 46 | Loss: 0.6680
# Fold 1 | Epoch 47 | Loss: 0.6668
# Fold 1 | Epoch 48 | Loss: 0.6665
# Fold 1 | Epoch 49 | Loss: 0.6648
# Fold 1 | Epoch 50 | Loss: 0.6646
# Fold 1 | Epoch 51 | Loss: 0.6639
# Fold 1 | Epoch 52 | Loss: 0.6631
# Fold 1 | Epoch 53 | Loss: 0.6619
# Fold 1 | Epoch 54 | Loss: 0.6612
# Fold 1 | Epoch 55 | Loss: 0.6608
# Fold 1 | Epoch 56 | Loss: 0.6603
# Fold 1 | Epoch 57 | Loss: 0.6590
# Fold 1 | Epoch 58 | Loss: 0.6585
# Fold 1 | Epoch 59 | Loss: 0.6579
# Fold 1 | Epoch 60 | Loss: 0.6578
# Fold 1 | Epoch 61 | Loss: 0.6569
# Fold 1 | Epoch 62 | Loss: 0.6564
# Fold 1 | Epoch 63 | Loss: 0.6557
# Fold 1 | Epoch 64 | Loss: 0.6549
# Fold 1 | Epoch 65 | Loss: 0.6544
# Fold 1 | Epoch 66 | Loss: 0.6544
# Fold 1 | Epoch 67 | Loss: 0.6535
# Fold 1 | Epoch 68 | Loss: 0.6531
# Fold 1 | Epoch 69 | Loss: 0.6521
# Fold 1 | Epoch 70 | Loss: 0.6519
# Fold 1 | Epoch 71 | Loss: 0.6514
# Fold 1 | Epoch 72 | Loss: 0.6508
# Fold 1 | Epoch 73 | Loss: 0.6506
# Fold 1 | Epoch 74 | Loss: 0.6497
# Fold 1 | Epoch 75 | Loss: 0.6496
# Fold 1 | Epoch 76 | Loss: 0.6489
# Fold 1 | Epoch 77 | Loss: 0.6483
# Fold 1 | Epoch 78 | Loss: 0.6484
# Fold 1 | Epoch 79 | Loss: 0.6485
# Fold 1 | Epoch 80 | Loss: 0.6473
# Fold 1 | Epoch 81 | Loss: 0.6466
# Fold 1 | Epoch 82 | Loss: 0.6462
# Fold 1 | Epoch 83 | Loss: 0.6466
# Fold 1 | Epoch 84 | Loss: 0.6454
# Fold 1 | Epoch 85 | Loss: 0.6456
# Fold 1 | Epoch 86 | Loss: 0.6453
# Fold 1 | Epoch 87 | Loss: 0.6446
# Fold 1 | Epoch 88 | Loss: 0.6447
# Fold 1 | Epoch 89 | Loss: 0.6444
# Fold 1 | Epoch 90 | Loss: 0.6443
# Fold 1 | Epoch 91 | Loss: 0.6436
# Fold 1 | Epoch 92 | Loss: 0.6437
# Fold 1 | Epoch 93 | Loss: 0.6431
# Fold 1 | Epoch 94 | Loss: 0.6424
# Fold 1 | Epoch 95 | Loss: 0.6422
# Fold 1 | Epoch 96 | Loss: 0.6415
# Fold 1 | Epoch 97 | Loss: 0.6424
# Fold 1 | Epoch 98 | Loss: 0.6411
# Fold 1 | Epoch 99 | Loss: 0.6409
# Fold 1 | Epoch 100 | Loss: 0.6407
# Fold 1 | Epoch 101 | Loss: 0.6407
# Fold 1 | Epoch 102 | Loss: 0.6405
# Fold 1 | Epoch 103 | Loss: 0.6396
# Fold 1 | Epoch 104 | Loss: 0.6395
# Fold 1 | Epoch 105 | Loss: 0.6393
# Fold 1 | Epoch 106 | Loss: 0.6388
# Fold 1 | Epoch 107 | Loss: 0.6389
# Fold 1 | Epoch 108 | Loss: 0.6390
# Fold 1 | Epoch 109 | Loss: 0.6387
# Fold 1 | Epoch 110 | Loss: 0.6388
# Fold 1 | Epoch 111 | Loss: 0.6382
# Fold 1 | Epoch 112 | Loss: 0.6386
# Fold 1 | Epoch 113 | Loss: 0.6379
# Fold 1 | Epoch 114 | Loss: 0.6371
# Fold 1 | Epoch 115 | Loss: 0.6375
# Fold 1 | Epoch 116 | Loss: 0.6370
# Fold 1 | Epoch 117 | Loss: 0.6370
# Fold 1 | Epoch 118 | Loss: 0.6366
# Fold 1 | Epoch 119 | Loss: 0.6368
# Fold 1 | Epoch 120 | Loss: 0.6359
# Fold 1 | Epoch 121 | Loss: 0.6357
# Fold 1 | Epoch 122 | Loss: 0.6364
# Fold 1 | Epoch 123 | Loss: 0.6354
# Fold 1 | Epoch 124 | Loss: 0.6359
# Fold 1 | Epoch 125 | Loss: 0.6355
# Fold 1 | Epoch 126 | Loss: 0.6354
# Fold 1 | Epoch 127 | Loss: 0.6344
# Fold 1 | Epoch 128 | Loss: 0.6348
# Fold 1 | Epoch 129 | Loss: 0.6350
# Fold 1 | Epoch 130 | Loss: 0.6350
# Fold 1 | Epoch 131 | Loss: 0.6345
# Fold 1 | Epoch 132 | Loss: 0.6341
# Fold 1 | Epoch 133 | Loss: 0.6336
# Fold 1 | Epoch 134 | Loss: 0.6338
# Fold 1 | Epoch 135 | Loss: 0.6339
# Fold 1 | Epoch 136 | Loss: 0.6340
# Fold 1 | Epoch 137 | Loss: 0.6330
# Fold 1 | Epoch 138 | Loss: 0.6339
# Fold 1 | Epoch 139 | Loss: 0.6334
# Fold 1 | Epoch 140 | Loss: 0.6327
# Fold 1 | Epoch 141 | Loss: 0.6329
# Fold 1 | Epoch 142 | Loss: 0.6325
# Fold 1 | Epoch 143 | Loss: 0.6319
# Fold 1 | Epoch 144 | Loss: 0.6328
# Fold 1 | Epoch 145 | Loss: 0.6322
# Fold 1 | Epoch 146 | Loss: 0.6323
# Fold 1 | Epoch 147 | Loss: 0.6313
# Fold 1 | Epoch 148 | Loss: 0.6315
# Fold 1 | Epoch 149 | Loss: 0.6318
# Fold 1 | Epoch 150 | Loss: 0.6322
# Fold 1 | Epoch 151 | Loss: 0.6319
# Fold 1 | Epoch 152 | Loss: 0.6314
# Fold 1 | Epoch 153 | Loss: 0.6313
# Fold 1 | Epoch 154 | Loss: 0.6314
# Fold 1 | Epoch 155 | Loss: 0.6310
# Fold 1 | Epoch 156 | Loss: 0.6313
# Fold 1 | Epoch 157 | Loss: 0.6310
# Fold 1 | Epoch 158 | Loss: 0.6315
# Fold 1 | Epoch 159 | Loss: 0.6311
# Fold 1 | Epoch 160 | Loss: 0.6307
# Fold 1 | Epoch 161 | Loss: 0.6304
# Fold 1 | Epoch 162 | Loss: 0.6303
# Fold 1 | Epoch 163 | Loss: 0.6300
# Fold 1 | Epoch 164 | Loss: 0.6297
# Fold 1 | Epoch 165 | Loss: 0.6295
# Fold 1 | Epoch 166 | Loss: 0.6295
# Fold 1 | Epoch 167 | Loss: 0.6299
# Fold 1 | Epoch 168 | Loss: 0.6294
# Fold 1 | Epoch 169 | Loss: 0.6295
# Fold 1 | Epoch 170 | Loss: 0.6301
# Fold 1 | Epoch 171 | Loss: 0.6292
# Fold 1 | Epoch 172 | Loss: 0.6296
# Fold 1 | Epoch 173 | Loss: 0.6287
# Fold 1 | Epoch 174 | Loss: 0.6285
# Fold 1 | Epoch 175 | Loss: 0.6290
# Fold 1 | Epoch 176 | Loss: 0.6286
# Fold 1 | Epoch 177 | Loss: 0.6289
# Fold 1 | Epoch 178 | Loss: 0.6297
# Fold 1 | Epoch 179 | Loss: 0.6284
# Fold 1 | Epoch 180 | Loss: 0.6284
# Fold 1 | Epoch 181 | Loss: 0.6279
# Fold 1 | Epoch 182 | Loss: 0.6290
# Fold 1 | Epoch 183 | Loss: 0.6282
# Fold 1 | Epoch 184 | Loss: 0.6287
# Fold 1 | Epoch 185 | Loss: 0.6283
# Fold 1 | Epoch 186 | Loss: 0.6281
# Fold 1 | Epoch 187 | Loss: 0.6281
# Fold 1 | Epoch 188 | Loss: 0.6283
# Fold 1 | Epoch 189 | Loss: 0.6279
# Fold 1 | Epoch 190 | Loss: 0.6273
# Fold 1 | Epoch 191 | Loss: 0.6277
# Fold 1 | Epoch 192 | Loss: 0.6280
# Fold 1 | Epoch 193 | Loss: 0.6272
# Fold 1 | Epoch 194 | Loss: 0.6279
# Fold 1 | Epoch 195 | Loss: 0.6275
# Fold 1 | Epoch 196 | Loss: 0.6272
# Fold 1 | Epoch 197 | Loss: 0.6278
# Fold 1 | Epoch 198 | Loss: 0.6273
# Fold 1 | Epoch 199 | Loss: 0.6268
# Fold 1 | Epoch 200 | Loss: 0.6269
# Fold 1 | Epoch 201 | Loss: 0.6273
# Fold 1 | Epoch 202 | Loss: 0.6270
# Fold 1 | Epoch 203 | Loss: 0.6269
# Fold 1 | Epoch 204 | Loss: 0.6266
# Fold 1 | Epoch 205 | Loss: 0.6260
# Fold 1 | Epoch 206 | Loss: 0.6269
# Fold 1 | Epoch 207 | Loss: 0.6263
# Fold 1 | Epoch 208 | Loss: 0.6262
# Fold 1 | Epoch 209 | Loss: 0.6263
# Fold 1 | Epoch 210 | Loss: 0.6268
# Fold 1 | Epoch 211 | Loss: 0.6272
# Fold 1 | Epoch 212 | Loss: 0.6264
# Fold 1 | Epoch 213 | Loss: 0.6262
# Fold 1 | Epoch 214 | Loss: 0.6262
# Fold 1 | Epoch 215 | Loss: 0.6258
# Fold 1 | Epoch 216 | Loss: 0.6258
# Fold 1 | Epoch 217 | Loss: 0.6259
# Fold 1 | Epoch 218 | Loss: 0.6261
# Fold 1 | Epoch 219 | Loss: 0.6259
# Fold 1 | Epoch 220 | Loss: 0.6251
# Fold 1 | Epoch 221 | Loss: 0.6252
# Fold 1 | Epoch 222 | Loss: 0.6255
# Fold 1 | Epoch 223 | Loss: 0.6255
# Fold 1 | Epoch 224 | Loss: 0.6251
# Fold 1 | Epoch 225 | Loss: 0.6255
# Fold 1 | Epoch 226 | Loss: 0.6248
# Fold 1 | Epoch 227 | Loss: 0.6257
# Fold 1 | Epoch 228 | Loss: 0.6248
# Fold 1 | Epoch 229 | Loss: 0.6260
# Fold 1 | Epoch 230 | Loss: 0.6249
# Fold 1 | Epoch 231 | Loss: 0.6257
# Fold 1 | Epoch 232 | Loss: 0.6255
# Fold 1 | Epoch 233 | Loss: 0.6253
# Fold 1 | Epoch 234 | Loss: 0.6245
# Fold 1 | Epoch 235 | Loss: 0.6253
# Fold 1 | Epoch 236 | Loss: 0.6248
# Fold 1 | Epoch 237 | Loss: 0.6255
# Fold 1 | Epoch 238 | Loss: 0.6245
# Fold 1 | Epoch 239 | Loss: 0.6245
# Fold 1 | Epoch 240 | Loss: 0.6247
# Fold 1 | Epoch 241 | Loss: 0.6253
# Fold 1 | Epoch 242 | Loss: 0.6242
# Fold 1 | Epoch 243 | Loss: 0.6241
# Fold 1 | Epoch 244 | Loss: 0.6245
# Fold 1 | Epoch 245 | Loss: 0.6243
# Fold 1 | Epoch 246 | Loss: 0.6240
# Fold 1 | Epoch 247 | Loss: 0.6244
# Fold 1 | Epoch 248 | Loss: 0.6250
# Fold 1 | Epoch 249 | Loss: 0.6240
# Fold 1 | Epoch 250 | Loss: 0.6240
# Fold 1 | Epoch 251 | Loss: 0.6244
# Fold 1 | Epoch 252 | Loss: 0.6243
# Fold 1 | Epoch 253 | Loss: 0.6244
# Fold 1 | Epoch 254 | Loss: 0.6242
# Fold 1 | Epoch 255 | Loss: 0.6235
# Fold 1 | Epoch 256 | Loss: 0.6239
# Fold 1 | Epoch 257 | Loss: 0.6237
# Fold 1 | Epoch 258 | Loss: 0.6249
# Fold 1 | Epoch 259 | Loss: 0.6239
# Fold 1 | Epoch 260 | Loss: 0.6233
# Fold 1 | Epoch 261 | Loss: 0.6233
# Fold 1 | Epoch 262 | Loss: 0.6234
# Fold 1 | Epoch 263 | Loss: 0.6235
# Fold 1 | Epoch 264 | Loss: 0.6241
# Fold 1 | Epoch 265 | Loss: 0.6241
# Fold 1 | Epoch 266 | Loss: 0.6235
# Fold 1 | Epoch 267 | Loss: 0.6244
# Fold 1 | Epoch 268 | Loss: 0.6245
# Fold 1 | Epoch 269 | Loss: 0.6225
# Fold 1 | Epoch 270 | Loss: 0.6234
# Fold 1 | Epoch 271 | Loss: 0.6239
# Fold 1 | Epoch 272 | Loss: 0.6229
# Fold 1 | Epoch 273 | Loss: 0.6231
# Fold 1 | Epoch 274 | Loss: 0.6226
# Fold 1 | Epoch 275 | Loss: 0.6235
# Fold 1 | Epoch 276 | Loss: 0.6237
# Fold 1 | Epoch 277 | Loss: 0.6233
# Fold 1 | Epoch 278 | Loss: 0.6227
# Fold 1 | Epoch 279 | Loss: 0.6242
# Fold 1 | Epoch 280 | Loss: 0.6233
# Fold 1 | Epoch 281 | Loss: 0.6228
# Fold 1 | Epoch 282 | Loss: 0.6233
# Fold 1 | Epoch 283 | Loss: 0.6226
# Fold 1 | Epoch 284 | Loss: 0.6221
# Fold 1 | Epoch 285 | Loss: 0.6224
# Fold 1 | Epoch 286 | Loss: 0.6227
# Fold 1 | Epoch 287 | Loss: 0.6229
# Fold 1 | Epoch 288 | Loss: 0.6228
# Fold 1 | Epoch 289 | Loss: 0.6225
# Fold 1 | Epoch 290 | Loss: 0.6222
# Fold 1 | Epoch 291 | Loss: 0.6220
# Fold 1 | Epoch 292 | Loss: 0.6218
# Fold 1 | Epoch 293 | Loss: 0.6226
# Fold 1 | Epoch 294 | Loss: 0.6225
# Fold 1 | Epoch 295 | Loss: 0.6218
# Fold 1 | Epoch 296 | Loss: 0.6227
# Fold 1 | Epoch 297 | Loss: 0.6224
# Fold 1 | Epoch 298 | Loss: 0.6224
# Fold 1 | Epoch 299 | Loss: 0.6219
# Fold 1 | Epoch 300 | Loss: 0.6220
#
# Starting Fold 2...
# Fold 2 | Epoch 1 | Loss: 0.8154
# Fold 2 | Epoch 2 | Loss: 0.7971
# Fold 2 | Epoch 3 | Loss: 0.7822
# Fold 2 | Epoch 4 | Loss: 0.7702
# Fold 2 | Epoch 5 | Loss: 0.7601
# Fold 2 | Epoch 6 | Loss: 0.7519
# Fold 2 | Epoch 7 | Loss: 0.7451
# Fold 2 | Epoch 8 | Loss: 0.7391
# Fold 2 | Epoch 9 | Loss: 0.7342
# Fold 2 | Epoch 10 | Loss: 0.7296
# Fold 2 | Epoch 11 | Loss: 0.7260
# Fold 2 | Epoch 12 | Loss: 0.7223
# Fold 2 | Epoch 13 | Loss: 0.7190
# Fold 2 | Epoch 14 | Loss: 0.7157
# Fold 2 | Epoch 15 | Loss: 0.7128
# Fold 2 | Epoch 16 | Loss: 0.7102
# Fold 2 | Epoch 17 | Loss: 0.7079
# Fold 2 | Epoch 18 | Loss: 0.7049
# Fold 2 | Epoch 19 | Loss: 0.7028
# Fold 2 | Epoch 20 | Loss: 0.7006
# Fold 2 | Epoch 21 | Loss: 0.6986
# Fold 2 | Epoch 22 | Loss: 0.6967
# Fold 2 | Epoch 23 | Loss: 0.6949
# Fold 2 | Epoch 24 | Loss: 0.6935
# Fold 2 | Epoch 25 | Loss: 0.6914
# Fold 2 | Epoch 26 | Loss: 0.6900
# Fold 2 | Epoch 27 | Loss: 0.6880
# Fold 2 | Epoch 28 | Loss: 0.6870
# Fold 2 | Epoch 29 | Loss: 0.6854
# Fold 2 | Epoch 30 | Loss: 0.6837
# Fold 2 | Epoch 31 | Loss: 0.6826
# Fold 2 | Epoch 32 | Loss: 0.6817
# Fold 2 | Epoch 33 | Loss: 0.6806
# Fold 2 | Epoch 34 | Loss: 0.6793
# Fold 2 | Epoch 35 | Loss: 0.6780
# Fold 2 | Epoch 36 | Loss: 0.6770
# Fold 2 | Epoch 37 | Loss: 0.6761
# Fold 2 | Epoch 38 | Loss: 0.6748
# Fold 2 | Epoch 39 | Loss: 0.6738
# Fold 2 | Epoch 40 | Loss: 0.6726
# Fold 2 | Epoch 41 | Loss: 0.6720
# Fold 2 | Epoch 42 | Loss: 0.6710
# Fold 2 | Epoch 43 | Loss: 0.6699
# Fold 2 | Epoch 44 | Loss: 0.6691
# Fold 2 | Epoch 45 | Loss: 0.6684
# Fold 2 | Epoch 46 | Loss: 0.6678
# Fold 2 | Epoch 47 | Loss: 0.6667
# Fold 2 | Epoch 48 | Loss: 0.6659
# Fold 2 | Epoch 49 | Loss: 0.6649
# Fold 2 | Epoch 50 | Loss: 0.6648
# Fold 2 | Epoch 51 | Loss: 0.6638
# Fold 2 | Epoch 52 | Loss: 0.6632
# Fold 2 | Epoch 53 | Loss: 0.6625
# Fold 2 | Epoch 54 | Loss: 0.6613
# Fold 2 | Epoch 55 | Loss: 0.6608
# Fold 2 | Epoch 56 | Loss: 0.6606
# Fold 2 | Epoch 57 | Loss: 0.6593
# Fold 2 | Epoch 58 | Loss: 0.6590
# Fold 2 | Epoch 59 | Loss: 0.6580
# Fold 2 | Epoch 60 | Loss: 0.6579
# Fold 2 | Epoch 61 | Loss: 0.6567
# Fold 2 | Epoch 62 | Loss: 0.6564
# Fold 2 | Epoch 63 | Loss: 0.6563
# Fold 2 | Epoch 64 | Loss: 0.6555
# Fold 2 | Epoch 65 | Loss: 0.6549
# Fold 2 | Epoch 66 | Loss: 0.6543
# Fold 2 | Epoch 67 | Loss: 0.6538
# Fold 2 | Epoch 68 | Loss: 0.6534
# Fold 2 | Epoch 69 | Loss: 0.6529
# Fold 2 | Epoch 70 | Loss: 0.6523
# Fold 2 | Epoch 71 | Loss: 0.6514
# Fold 2 | Epoch 72 | Loss: 0.6515
# Fold 2 | Epoch 73 | Loss: 0.6510
# Fold 2 | Epoch 74 | Loss: 0.6512
# Fold 2 | Epoch 75 | Loss: 0.6508
# Fold 2 | Epoch 76 | Loss: 0.6492
# Fold 2 | Epoch 77 | Loss: 0.6494
# Fold 2 | Epoch 78 | Loss: 0.6487
# Fold 2 | Epoch 79 | Loss: 0.6485
# Fold 2 | Epoch 80 | Loss: 0.6478
# Fold 2 | Epoch 81 | Loss: 0.6477
# Fold 2 | Epoch 82 | Loss: 0.6475
# Fold 2 | Epoch 83 | Loss: 0.6467
# Fold 2 | Epoch 84 | Loss: 0.6464
# Fold 2 | Epoch 85 | Loss: 0.6460
# Fold 2 | Epoch 86 | Loss: 0.6461
# Fold 2 | Epoch 87 | Loss: 0.6457
# Fold 2 | Epoch 88 | Loss: 0.6449
# Fold 2 | Epoch 89 | Loss: 0.6448
# Fold 2 | Epoch 90 | Loss: 0.6444
# Fold 2 | Epoch 91 | Loss: 0.6440
# Fold 2 | Epoch 92 | Loss: 0.6436
# Fold 2 | Epoch 93 | Loss: 0.6432
# Fold 2 | Epoch 94 | Loss: 0.6432
# Fold 2 | Epoch 95 | Loss: 0.6435
# Fold 2 | Epoch 96 | Loss: 0.6423
# Fold 2 | Epoch 97 | Loss: 0.6422
# Fold 2 | Epoch 98 | Loss: 0.6430
# Fold 2 | Epoch 99 | Loss: 0.6414
# Fold 2 | Epoch 100 | Loss: 0.6422
# Fold 2 | Epoch 101 | Loss: 0.6411
# Fold 2 | Epoch 102 | Loss: 0.6409
# Fold 2 | Epoch 103 | Loss: 0.6410
# Fold 2 | Epoch 104 | Loss: 0.6401
# Fold 2 | Epoch 105 | Loss: 0.6405
# Fold 2 | Epoch 106 | Loss: 0.6404
# Fold 2 | Epoch 107 | Loss: 0.6397
# Fold 2 | Epoch 108 | Loss: 0.6399
# Fold 2 | Epoch 109 | Loss: 0.6395
# Fold 2 | Epoch 110 | Loss: 0.6390
# Fold 2 | Epoch 111 | Loss: 0.6394
# Fold 2 | Epoch 112 | Loss: 0.6386
# Fold 2 | Epoch 113 | Loss: 0.6382
# Fold 2 | Epoch 114 | Loss: 0.6382
# Fold 2 | Epoch 115 | Loss: 0.6383
# Fold 2 | Epoch 116 | Loss: 0.6377
# Fold 2 | Epoch 117 | Loss: 0.6379
# Fold 2 | Epoch 118 | Loss: 0.6372
# Fold 2 | Epoch 119 | Loss: 0.6374
# Fold 2 | Epoch 120 | Loss: 0.6378
# Fold 2 | Epoch 121 | Loss: 0.6363
# Fold 2 | Epoch 122 | Loss: 0.6370
# Fold 2 | Epoch 123 | Loss: 0.6362
# Fold 2 | Epoch 124 | Loss: 0.6365
# Fold 2 | Epoch 125 | Loss: 0.6363
# Fold 2 | Epoch 126 | Loss: 0.6359
# Fold 2 | Epoch 127 | Loss: 0.6364
# Fold 2 | Epoch 128 | Loss: 0.6353
# Fold 2 | Epoch 129 | Loss: 0.6350
# Fold 2 | Epoch 130 | Loss: 0.6355
# Fold 2 | Epoch 131 | Loss: 0.6352
# Fold 2 | Epoch 132 | Loss: 0.6351
# Fold 2 | Epoch 133 | Loss: 0.6350
# Fold 2 | Epoch 134 | Loss: 0.6350
# Fold 2 | Epoch 135 | Loss: 0.6352
# Fold 2 | Epoch 136 | Loss: 0.6348
# Fold 2 | Epoch 137 | Loss: 0.6336
# Fold 2 | Epoch 138 | Loss: 0.6341
# Fold 2 | Epoch 139 | Loss: 0.6341
# Fold 2 | Epoch 140 | Loss: 0.6343
# Fold 2 | Epoch 141 | Loss: 0.6334
# Fold 2 | Epoch 142 | Loss: 0.6341
# Fold 2 | Epoch 143 | Loss: 0.6332
# Fold 2 | Epoch 144 | Loss: 0.6338
# Fold 2 | Epoch 145 | Loss: 0.6331
# Fold 2 | Epoch 146 | Loss: 0.6331
# Fold 2 | Epoch 147 | Loss: 0.6326
# Fold 2 | Epoch 148 | Loss: 0.6329
# Fold 2 | Epoch 149 | Loss: 0.6330
# Fold 2 | Epoch 150 | Loss: 0.6330
# Fold 2 | Epoch 151 | Loss: 0.6326
# Fold 2 | Epoch 152 | Loss: 0.6329
# Fold 2 | Epoch 153 | Loss: 0.6320
# Fold 2 | Epoch 154 | Loss: 0.6322
# Fold 2 | Epoch 155 | Loss: 0.6317
# Fold 2 | Epoch 156 | Loss: 0.6318
# Fold 2 | Epoch 157 | Loss: 0.6319
# Fold 2 | Epoch 158 | Loss: 0.6318
# Fold 2 | Epoch 159 | Loss: 0.6317
# Fold 2 | Epoch 160 | Loss: 0.6315
# Fold 2 | Epoch 161 | Loss: 0.6317
# Fold 2 | Epoch 162 | Loss: 0.6319
# Fold 2 | Epoch 163 | Loss: 0.6314
# Fold 2 | Epoch 164 | Loss: 0.6313
# Fold 2 | Epoch 165 | Loss: 0.6312
# Fold 2 | Epoch 166 | Loss: 0.6305
# Fold 2 | Epoch 167 | Loss: 0.6305
# Fold 2 | Epoch 168 | Loss: 0.6305
# Fold 2 | Epoch 169 | Loss: 0.6311
# Fold 2 | Epoch 170 | Loss: 0.6305
# Fold 2 | Epoch 171 | Loss: 0.6304
# Fold 2 | Epoch 172 | Loss: 0.6302
# Fold 2 | Epoch 173 | Loss: 0.6300
# Fold 2 | Epoch 174 | Loss: 0.6306
# Fold 2 | Epoch 175 | Loss: 0.6304
# Fold 2 | Epoch 176 | Loss: 0.6302
# Fold 2 | Epoch 177 | Loss: 0.6301
# Fold 2 | Epoch 178 | Loss: 0.6293
# Fold 2 | Epoch 179 | Loss: 0.6297
# Fold 2 | Epoch 180 | Loss: 0.6295
# Fold 2 | Epoch 181 | Loss: 0.6298
# Fold 2 | Epoch 182 | Loss: 0.6293
# Fold 2 | Epoch 183 | Loss: 0.6293
# Fold 2 | Epoch 184 | Loss: 0.6294
# Fold 2 | Epoch 185 | Loss: 0.6294
# Fold 2 | Epoch 186 | Loss: 0.6288
# Fold 2 | Epoch 187 | Loss: 0.6293
# Fold 2 | Epoch 188 | Loss: 0.6291
# Fold 2 | Epoch 189 | Loss: 0.6284
# Fold 2 | Epoch 190 | Loss: 0.6289
# Fold 2 | Epoch 191 | Loss: 0.6290
# Fold 2 | Epoch 192 | Loss: 0.6280
# Fold 2 | Epoch 193 | Loss: 0.6284
# Fold 2 | Epoch 194 | Loss: 0.6282
# Fold 2 | Epoch 195 | Loss: 0.6288
# Fold 2 | Epoch 196 | Loss: 0.6280
# Fold 2 | Epoch 197 | Loss: 0.6280
# Fold 2 | Epoch 198 | Loss: 0.6290
# Fold 2 | Epoch 199 | Loss: 0.6289
# Fold 2 | Epoch 200 | Loss: 0.6277
# Fold 2 | Epoch 201 | Loss: 0.6277
# Fold 2 | Epoch 202 | Loss: 0.6281
# Fold 2 | Epoch 203 | Loss: 0.6278
# Fold 2 | Epoch 204 | Loss: 0.6282
# Fold 2 | Epoch 205 | Loss: 0.6280
# Fold 2 | Epoch 206 | Loss: 0.6276
# Fold 2 | Epoch 207 | Loss: 0.6279
# Fold 2 | Epoch 208 | Loss: 0.6273
# Fold 2 | Epoch 209 | Loss: 0.6275
# Fold 2 | Epoch 210 | Loss: 0.6273
# Fold 2 | Epoch 211 | Loss: 0.6269
# Fold 2 | Epoch 212 | Loss: 0.6271
# Fold 2 | Epoch 213 | Loss: 0.6272
# Fold 2 | Epoch 214 | Loss: 0.6270
# Fold 2 | Epoch 215 | Loss: 0.6271
# Fold 2 | Epoch 216 | Loss: 0.6272
# Fold 2 | Epoch 217 | Loss: 0.6270
# Fold 2 | Epoch 218 | Loss: 0.6265
# Fold 2 | Epoch 219 | Loss: 0.6265
# Fold 2 | Epoch 220 | Loss: 0.6274
# Fold 2 | Epoch 221 | Loss: 0.6263
# Fold 2 | Epoch 222 | Loss: 0.6269
# Fold 2 | Epoch 223 | Loss: 0.6278
# Fold 2 | Epoch 224 | Loss: 0.6265
# Fold 2 | Epoch 225 | Loss: 0.6265
# Fold 2 | Epoch 226 | Loss: 0.6267
# Fold 2 | Epoch 227 | Loss: 0.6262
# Fold 2 | Epoch 228 | Loss: 0.6265
# Fold 2 | Epoch 229 | Loss: 0.6263
# Fold 2 | Epoch 230 | Loss: 0.6263
# Fold 2 | Epoch 231 | Loss: 0.6261
# Fold 2 | Epoch 232 | Loss: 0.6260
# Fold 2 | Epoch 233 | Loss: 0.6260
# Fold 2 | Epoch 234 | Loss: 0.6255
# Fold 2 | Epoch 235 | Loss: 0.6261
# Fold 2 | Epoch 236 | Loss: 0.6254
# Fold 2 | Epoch 237 | Loss: 0.6259
# Fold 2 | Epoch 238 | Loss: 0.6263
# Fold 2 | Epoch 239 | Loss: 0.6254
# Fold 2 | Epoch 240 | Loss: 0.6260
# Fold 2 | Epoch 241 | Loss: 0.6259
# Fold 2 | Epoch 242 | Loss: 0.6258
# Fold 2 | Epoch 243 | Loss: 0.6251
# Fold 2 | Epoch 244 | Loss: 0.6259
# Fold 2 | Epoch 245 | Loss: 0.6254
# Fold 2 | Epoch 246 | Loss: 0.6260
# Fold 2 | Epoch 247 | Loss: 0.6249
# Fold 2 | Epoch 248 | Loss: 0.6247
# Fold 2 | Epoch 249 | Loss: 0.6251
# Fold 2 | Epoch 250 | Loss: 0.6249
# Fold 2 | Epoch 251 | Loss: 0.6254
# Fold 2 | Epoch 252 | Loss: 0.6246
# Fold 2 | Epoch 253 | Loss: 0.6247
# Fold 2 | Epoch 254 | Loss: 0.6249
# Fold 2 | Epoch 255 | Loss: 0.6252
# Fold 2 | Epoch 256 | Loss: 0.6245
# Fold 2 | Epoch 257 | Loss: 0.6243
# Fold 2 | Epoch 258 | Loss: 0.6250
# Fold 2 | Epoch 259 | Loss: 0.6249
# Fold 2 | Epoch 260 | Loss: 0.6250
# Fold 2 | Epoch 261 | Loss: 0.6244
# Fold 2 | Epoch 262 | Loss: 0.6247
# Fold 2 | Epoch 263 | Loss: 0.6242
# Fold 2 | Epoch 264 | Loss: 0.6245
# Fold 2 | Epoch 265 | Loss: 0.6246
# Fold 2 | Epoch 266 | Loss: 0.6244
# Fold 2 | Epoch 267 | Loss: 0.6245
# Fold 2 | Epoch 268 | Loss: 0.6243
# Fold 2 | Epoch 269 | Loss: 0.6238
# Fold 2 | Epoch 270 | Loss: 0.6243
# Fold 2 | Epoch 271 | Loss: 0.6240
# Fold 2 | Epoch 272 | Loss: 0.6245
# Fold 2 | Epoch 273 | Loss: 0.6241
# Fold 2 | Epoch 274 | Loss: 0.6238
# Fold 2 | Epoch 275 | Loss: 0.6246
# Fold 2 | Epoch 276 | Loss: 0.6236
# Fold 2 | Epoch 277 | Loss: 0.6237
# Fold 2 | Epoch 278 | Loss: 0.6234
# Fold 2 | Epoch 279 | Loss: 0.6242
# Fold 2 | Epoch 280 | Loss: 0.6241
# Fold 2 | Epoch 281 | Loss: 0.6238
# Fold 2 | Epoch 282 | Loss: 0.6239
# Fold 2 | Epoch 283 | Loss: 0.6235
# Fold 2 | Epoch 284 | Loss: 0.6234
# Fold 2 | Epoch 285 | Loss: 0.6236
# Fold 2 | Epoch 286 | Loss: 0.6246
# Fold 2 | Epoch 287 | Loss: 0.6241
# Fold 2 | Epoch 288 | Loss: 0.6243
# Fold 2 | Epoch 289 | Loss: 0.6238
# Fold 2 | Epoch 290 | Loss: 0.6234
# Fold 2 | Epoch 291 | Loss: 0.6237
# Fold 2 | Epoch 292 | Loss: 0.6236
# Fold 2 | Epoch 293 | Loss: 0.6232
# Fold 2 | Epoch 294 | Loss: 0.6238
# Fold 2 | Epoch 295 | Loss: 0.6236
# Fold 2 | Epoch 296 | Loss: 0.6231
# Fold 2 | Epoch 297 | Loss: 0.6232
# Fold 2 | Epoch 298 | Loss: 0.6237
# Fold 2 | Epoch 299 | Loss: 0.6239
# Fold 2 | Epoch 300 | Loss: 0.6234
#
# Starting Fold 3...
# Fold 3 | Epoch 1 | Loss: 0.8230
# Fold 3 | Epoch 2 | Loss: 0.8031
# Fold 3 | Epoch 3 | Loss: 0.7869
# Fold 3 | Epoch 4 | Loss: 0.7743
# Fold 3 | Epoch 5 | Loss: 0.7635
# Fold 3 | Epoch 6 | Loss: 0.7546
# Fold 3 | Epoch 7 | Loss: 0.7471
# Fold 3 | Epoch 8 | Loss: 0.7413
# Fold 3 | Epoch 9 | Loss: 0.7359
# Fold 3 | Epoch 10 | Loss: 0.7317
# Fold 3 | Epoch 11 | Loss: 0.7274
# Fold 3 | Epoch 12 | Loss: 0.7241
# Fold 3 | Epoch 13 | Loss: 0.7207
# Fold 3 | Epoch 14 | Loss: 0.7179
# Fold 3 | Epoch 15 | Loss: 0.7150
# Fold 3 | Epoch 16 | Loss: 0.7126
# Fold 3 | Epoch 17 | Loss: 0.7101
# Fold 3 | Epoch 18 | Loss: 0.7075
# Fold 3 | Epoch 19 | Loss: 0.7056
# Fold 3 | Epoch 20 | Loss: 0.7030
# Fold 3 | Epoch 21 | Loss: 0.7009
# Fold 3 | Epoch 22 | Loss: 0.6992
# Fold 3 | Epoch 23 | Loss: 0.6974
# Fold 3 | Epoch 24 | Loss: 0.6956
# Fold 3 | Epoch 25 | Loss: 0.6936
# Fold 3 | Epoch 26 | Loss: 0.6923
# Fold 3 | Epoch 27 | Loss: 0.6908
# Fold 3 | Epoch 28 | Loss: 0.6891
# Fold 3 | Epoch 29 | Loss: 0.6876
# Fold 3 | Epoch 30 | Loss: 0.6861
# Fold 3 | Epoch 31 | Loss: 0.6850
# Fold 3 | Epoch 32 | Loss: 0.6837
# Fold 3 | Epoch 33 | Loss: 0.6826
# Fold 3 | Epoch 34 | Loss: 0.6813
# Fold 3 | Epoch 35 | Loss: 0.6799
# Fold 3 | Epoch 36 | Loss: 0.6788
# Fold 3 | Epoch 37 | Loss: 0.6777
# Fold 3 | Epoch 38 | Loss: 0.6766
# Fold 3 | Epoch 39 | Loss: 0.6756
# Fold 3 | Epoch 40 | Loss: 0.6744
# Fold 3 | Epoch 41 | Loss: 0.6737
# Fold 3 | Epoch 42 | Loss: 0.6733
# Fold 3 | Epoch 43 | Loss: 0.6722
# Fold 3 | Epoch 44 | Loss: 0.6712
# Fold 3 | Epoch 45 | Loss: 0.6702
# Fold 3 | Epoch 46 | Loss: 0.6692
# Fold 3 | Epoch 47 | Loss: 0.6684
# Fold 3 | Epoch 48 | Loss: 0.6674
# Fold 3 | Epoch 49 | Loss: 0.6667
# Fold 3 | Epoch 50 | Loss: 0.6661
# Fold 3 | Epoch 51 | Loss: 0.6652
# Fold 3 | Epoch 52 | Loss: 0.6649
# Fold 3 | Epoch 53 | Loss: 0.6639
# Fold 3 | Epoch 54 | Loss: 0.6631
# Fold 3 | Epoch 55 | Loss: 0.6624
# Fold 3 | Epoch 56 | Loss: 0.6617
# Fold 3 | Epoch 57 | Loss: 0.6610
# Fold 3 | Epoch 58 | Loss: 0.6605
# Fold 3 | Epoch 59 | Loss: 0.6594
# Fold 3 | Epoch 60 | Loss: 0.6593
# Fold 3 | Epoch 61 | Loss: 0.6585
# Fold 3 | Epoch 62 | Loss: 0.6581
# Fold 3 | Epoch 63 | Loss: 0.6576
# Fold 3 | Epoch 64 | Loss: 0.6563
# Fold 3 | Epoch 65 | Loss: 0.6563
# Fold 3 | Epoch 66 | Loss: 0.6557
# Fold 3 | Epoch 67 | Loss: 0.6553
# Fold 3 | Epoch 68 | Loss: 0.6548
# Fold 3 | Epoch 69 | Loss: 0.6546
# Fold 3 | Epoch 70 | Loss: 0.6536
# Fold 3 | Epoch 71 | Loss: 0.6532
# Fold 3 | Epoch 72 | Loss: 0.6524
# Fold 3 | Epoch 73 | Loss: 0.6523
# Fold 3 | Epoch 74 | Loss: 0.6519
# Fold 3 | Epoch 75 | Loss: 0.6511
# Fold 3 | Epoch 76 | Loss: 0.6512
# Fold 3 | Epoch 77 | Loss: 0.6504
# Fold 3 | Epoch 78 | Loss: 0.6501
# Fold 3 | Epoch 79 | Loss: 0.6498
# Fold 3 | Epoch 80 | Loss: 0.6487
# Fold 3 | Epoch 81 | Loss: 0.6488
# Fold 3 | Epoch 82 | Loss: 0.6487
# Fold 3 | Epoch 83 | Loss: 0.6476
# Fold 3 | Epoch 84 | Loss: 0.6476
# Fold 3 | Epoch 85 | Loss: 0.6477
# Fold 3 | Epoch 86 | Loss: 0.6469
# Fold 3 | Epoch 87 | Loss: 0.6465
# Fold 3 | Epoch 88 | Loss: 0.6464
# Fold 3 | Epoch 89 | Loss: 0.6457
# Fold 3 | Epoch 90 | Loss: 0.6457
# Fold 3 | Epoch 91 | Loss: 0.6452
# Fold 3 | Epoch 92 | Loss: 0.6448
# Fold 3 | Epoch 93 | Loss: 0.6452
# Fold 3 | Epoch 94 | Loss: 0.6448
# Fold 3 | Epoch 95 | Loss: 0.6440
# Fold 3 | Epoch 96 | Loss: 0.6437
# Fold 3 | Epoch 97 | Loss: 0.6434
# Fold 3 | Epoch 98 | Loss: 0.6431
# Fold 3 | Epoch 99 | Loss: 0.6429
# Fold 3 | Epoch 100 | Loss: 0.6430
# Fold 3 | Epoch 101 | Loss: 0.6425
# Fold 3 | Epoch 102 | Loss: 0.6422
# Fold 3 | Epoch 103 | Loss: 0.6416
# Fold 3 | Epoch 104 | Loss: 0.6419
# Fold 3 | Epoch 105 | Loss: 0.6412
# Fold 3 | Epoch 106 | Loss: 0.6413
# Fold 3 | Epoch 107 | Loss: 0.6409
# Fold 3 | Epoch 108 | Loss: 0.6405
# Fold 3 | Epoch 109 | Loss: 0.6403
# Fold 3 | Epoch 110 | Loss: 0.6404
# Fold 3 | Epoch 111 | Loss: 0.6396
# Fold 3 | Epoch 112 | Loss: 0.6400
# Fold 3 | Epoch 113 | Loss: 0.6400
# Fold 3 | Epoch 114 | Loss: 0.6391
# Fold 3 | Epoch 115 | Loss: 0.6395
# Fold 3 | Epoch 116 | Loss: 0.6393
# Fold 3 | Epoch 117 | Loss: 0.6387
# Fold 3 | Epoch 118 | Loss: 0.6386
# Fold 3 | Epoch 119 | Loss: 0.6380
# Fold 3 | Epoch 120 | Loss: 0.6383
# Fold 3 | Epoch 121 | Loss: 0.6385
# Fold 3 | Epoch 122 | Loss: 0.6379
# Fold 3 | Epoch 123 | Loss: 0.6378
# Fold 3 | Epoch 124 | Loss: 0.6373
# Fold 3 | Epoch 125 | Loss: 0.6373
# Fold 3 | Epoch 126 | Loss: 0.6371
# Fold 3 | Epoch 127 | Loss: 0.6367
# Fold 3 | Epoch 128 | Loss: 0.6372
# Fold 3 | Epoch 129 | Loss: 0.6366
# Fold 3 | Epoch 130 | Loss: 0.6366
# Fold 3 | Epoch 131 | Loss: 0.6362
# Fold 3 | Epoch 132 | Loss: 0.6364
# Fold 3 | Epoch 133 | Loss: 0.6354
# Fold 3 | Epoch 134 | Loss: 0.6357
# Fold 3 | Epoch 135 | Loss: 0.6353
# Fold 3 | Epoch 136 | Loss: 0.6352
# Fold 3 | Epoch 137 | Loss: 0.6354
# Fold 3 | Epoch 138 | Loss: 0.6352
# Fold 3 | Epoch 139 | Loss: 0.6353
# Fold 3 | Epoch 140 | Loss: 0.6344
# Fold 3 | Epoch 141 | Loss: 0.6347
# Fold 3 | Epoch 142 | Loss: 0.6347
# Fold 3 | Epoch 143 | Loss: 0.6345
# Fold 3 | Epoch 144 | Loss: 0.6346
# Fold 3 | Epoch 145 | Loss: 0.6336
# Fold 3 | Epoch 146 | Loss: 0.6343
# Fold 3 | Epoch 147 | Loss: 0.6338
# Fold 3 | Epoch 148 | Loss: 0.6343
# Fold 3 | Epoch 149 | Loss: 0.6333
# Fold 3 | Epoch 150 | Loss: 0.6342
# Fold 3 | Epoch 151 | Loss: 0.6336
# Fold 3 | Epoch 152 | Loss: 0.6335
# Fold 3 | Epoch 153 | Loss: 0.6335
# Fold 3 | Epoch 154 | Loss: 0.6327
# Fold 3 | Epoch 155 | Loss: 0.6333
# Fold 3 | Epoch 156 | Loss: 0.6327
# Fold 3 | Epoch 157 | Loss: 0.6327
# Fold 3 | Epoch 158 | Loss: 0.6323
# Fold 3 | Epoch 159 | Loss: 0.6328
# Fold 3 | Epoch 160 | Loss: 0.6319
# Fold 3 | Epoch 161 | Loss: 0.6322
# Fold 3 | Epoch 162 | Loss: 0.6322
# Fold 3 | Epoch 163 | Loss: 0.6320
# Fold 3 | Epoch 164 | Loss: 0.6318
# Fold 3 | Epoch 165 | Loss: 0.6319
# Fold 3 | Epoch 166 | Loss: 0.6315
# Fold 3 | Epoch 167 | Loss: 0.6319
# Fold 3 | Epoch 168 | Loss: 0.6308
# Fold 3 | Epoch 169 | Loss: 0.6310
# Fold 3 | Epoch 170 | Loss: 0.6313
# Fold 3 | Epoch 171 | Loss: 0.6312
# Fold 3 | Epoch 172 | Loss: 0.6309
# Fold 3 | Epoch 173 | Loss: 0.6313
# Fold 3 | Epoch 174 | Loss: 0.6312
# Fold 3 | Epoch 175 | Loss: 0.6309
# Fold 3 | Epoch 176 | Loss: 0.6313
# Fold 3 | Epoch 177 | Loss: 0.6306
# Fold 3 | Epoch 178 | Loss: 0.6309
# Fold 3 | Epoch 179 | Loss: 0.6307
# Fold 3 | Epoch 180 | Loss: 0.6304
# Fold 3 | Epoch 181 | Loss: 0.6302
# Fold 3 | Epoch 182 | Loss: 0.6303
# Fold 3 | Epoch 183 | Loss: 0.6298
# Fold 3 | Epoch 184 | Loss: 0.6308
# Fold 3 | Epoch 185 | Loss: 0.6299
# Fold 3 | Epoch 186 | Loss: 0.6303
# Fold 3 | Epoch 187 | Loss: 0.6297
# Fold 3 | Epoch 188 | Loss: 0.6292
# Fold 3 | Epoch 189 | Loss: 0.6294
# Fold 3 | Epoch 190 | Loss: 0.6289
# Fold 3 | Epoch 191 | Loss: 0.6295
# Fold 3 | Epoch 192 | Loss: 0.6293
# Fold 3 | Epoch 193 | Loss: 0.6295
# Fold 3 | Epoch 194 | Loss: 0.6295
# Fold 3 | Epoch 195 | Loss: 0.6289
# Fold 3 | Epoch 196 | Loss: 0.6295
# Fold 3 | Epoch 197 | Loss: 0.6292
# Fold 3 | Epoch 198 | Loss: 0.6293
# Fold 3 | Epoch 199 | Loss: 0.6295
# Fold 3 | Epoch 200 | Loss: 0.6288
# Fold 3 | Epoch 201 | Loss: 0.6285
# Fold 3 | Epoch 202 | Loss: 0.6290
# Fold 3 | Epoch 203 | Loss: 0.6285
# Fold 3 | Epoch 204 | Loss: 0.6287
# Fold 3 | Epoch 205 | Loss: 0.6284
# Fold 3 | Epoch 206 | Loss: 0.6288
# Fold 3 | Epoch 207 | Loss: 0.6284
# Fold 3 | Epoch 208 | Loss: 0.6282
# Fold 3 | Epoch 209 | Loss: 0.6284
# Fold 3 | Epoch 210 | Loss: 0.6282
# Fold 3 | Epoch 211 | Loss: 0.6278
# Fold 3 | Epoch 212 | Loss: 0.6272
# Fold 3 | Epoch 213 | Loss: 0.6281
# Fold 3 | Epoch 214 | Loss: 0.6277
# Fold 3 | Epoch 215 | Loss: 0.6281
# Fold 3 | Epoch 216 | Loss: 0.6280
# Fold 3 | Epoch 217 | Loss: 0.6282
# Fold 3 | Epoch 218 | Loss: 0.6277
# Fold 3 | Epoch 219 | Loss: 0.6271
# Fold 3 | Epoch 220 | Loss: 0.6270
# Fold 3 | Epoch 221 | Loss: 0.6278
# Fold 3 | Epoch 222 | Loss: 0.6272
# Fold 3 | Epoch 223 | Loss: 0.6273
# Fold 3 | Epoch 224 | Loss: 0.6278
# Fold 3 | Epoch 225 | Loss: 0.6270
# Fold 3 | Epoch 226 | Loss: 0.6275
# Fold 3 | Epoch 227 | Loss: 0.6275
# Fold 3 | Epoch 228 | Loss: 0.6271
# Fold 3 | Epoch 229 | Loss: 0.6267
# Fold 3 | Epoch 230 | Loss: 0.6264
# Fold 3 | Epoch 231 | Loss: 0.6274
# Fold 3 | Epoch 232 | Loss: 0.6270
# Fold 3 | Epoch 233 | Loss: 0.6266
# Fold 3 | Epoch 234 | Loss: 0.6262
# Fold 3 | Epoch 235 | Loss: 0.6263
# Fold 3 | Epoch 236 | Loss: 0.6269
# Fold 3 | Epoch 237 | Loss: 0.6267
# Fold 3 | Epoch 238 | Loss: 0.6270
# Fold 3 | Epoch 239 | Loss: 0.6266
# Fold 3 | Epoch 240 | Loss: 0.6266
# Fold 3 | Epoch 241 | Loss: 0.6268
# Fold 3 | Epoch 242 | Loss: 0.6265
# Fold 3 | Epoch 243 | Loss: 0.6268
# Fold 3 | Epoch 244 | Loss: 0.6266
# Fold 3 | Epoch 245 | Loss: 0.6261
# Fold 3 | Epoch 246 | Loss: 0.6265
# Fold 3 | Epoch 247 | Loss: 0.6264
# Fold 3 | Epoch 248 | Loss: 0.6251
# Fold 3 | Epoch 249 | Loss: 0.6266
# Fold 3 | Epoch 250 | Loss: 0.6258
# Fold 3 | Epoch 251 | Loss: 0.6260
# Fold 3 | Epoch 252 | Loss: 0.6255
# Fold 3 | Epoch 253 | Loss: 0.6263
# Fold 3 | Epoch 254 | Loss: 0.6261
# Fold 3 | Epoch 255 | Loss: 0.6262
# Fold 3 | Epoch 256 | Loss: 0.6254
# Fold 3 | Epoch 257 | Loss: 0.6257
# Fold 3 | Epoch 258 | Loss: 0.6261
# Fold 3 | Epoch 259 | Loss: 0.6258
# Fold 3 | Epoch 260 | Loss: 0.6250
# Fold 3 | Epoch 261 | Loss: 0.6253
# Fold 3 | Epoch 262 | Loss: 0.6253
# Fold 3 | Epoch 263 | Loss: 0.6247
# Fold 3 | Epoch 264 | Loss: 0.6257
# Fold 3 | Epoch 265 | Loss: 0.6250
# Fold 3 | Epoch 266 | Loss: 0.6254
# Fold 3 | Epoch 267 | Loss: 0.6253
# Fold 3 | Epoch 268 | Loss: 0.6256
# Fold 3 | Epoch 269 | Loss: 0.6246
# Fold 3 | Epoch 270 | Loss: 0.6252
# Fold 3 | Epoch 271 | Loss: 0.6248
# Fold 3 | Epoch 272 | Loss: 0.6251
# Fold 3 | Epoch 273 | Loss: 0.6240
# Fold 3 | Epoch 274 | Loss: 0.6246
# Fold 3 | Epoch 275 | Loss: 0.6251
# Fold 3 | Epoch 276 | Loss: 0.6250
# Fold 3 | Epoch 277 | Loss: 0.6252
# Fold 3 | Epoch 278 | Loss: 0.6257
# Fold 3 | Epoch 279 | Loss: 0.6245
# Fold 3 | Epoch 280 | Loss: 0.6247
# Fold 3 | Epoch 281 | Loss: 0.6239
# Fold 3 | Epoch 282 | Loss: 0.6249
# Fold 3 | Epoch 283 | Loss: 0.6251
# Fold 3 | Epoch 284 | Loss: 0.6248
# Fold 3 | Epoch 285 | Loss: 0.6244
# Fold 3 | Epoch 286 | Loss: 0.6252
# Fold 3 | Epoch 287 | Loss: 0.6243
# Fold 3 | Epoch 288 | Loss: 0.6244
# Fold 3 | Epoch 289 | Loss: 0.6246
# Fold 3 | Epoch 290 | Loss: 0.6251
# Fold 3 | Epoch 291 | Loss: 0.6249
# Fold 3 | Epoch 292 | Loss: 0.6247
# Fold 3 | Epoch 293 | Loss: 0.6244
# Fold 3 | Epoch 294 | Loss: 0.6237
# Fold 3 | Epoch 295 | Loss: 0.6234
# Fold 3 | Epoch 296 | Loss: 0.6242
# Fold 3 | Epoch 297 | Loss: 0.6246
# Fold 3 | Epoch 298 | Loss: 0.6243
# Fold 3 | Epoch 299 | Loss: 0.6233
# Fold 3 | Epoch 300 | Loss: 0.6240
#
# Starting Fold 4...
# Fold 4 | Epoch 1 | Loss: 0.8259
# Fold 4 | Epoch 2 | Loss: 0.8062
# Fold 4 | Epoch 3 | Loss: 0.7905
# Fold 4 | Epoch 4 | Loss: 0.7772
# Fold 4 | Epoch 5 | Loss: 0.7660
# Fold 4 | Epoch 6 | Loss: 0.7574
# Fold 4 | Epoch 7 | Loss: 0.7498
# Fold 4 | Epoch 8 | Loss: 0.7436
# Fold 4 | Epoch 9 | Loss: 0.7384
# Fold 4 | Epoch 10 | Loss: 0.7335
# Fold 4 | Epoch 11 | Loss: 0.7299
# Fold 4 | Epoch 12 | Loss: 0.7261
# Fold 4 | Epoch 13 | Loss: 0.7225
# Fold 4 | Epoch 14 | Loss: 0.7194
# Fold 4 | Epoch 15 | Loss: 0.7165
# Fold 4 | Epoch 16 | Loss: 0.7136
# Fold 4 | Epoch 17 | Loss: 0.7110
# Fold 4 | Epoch 18 | Loss: 0.7086
# Fold 4 | Epoch 19 | Loss: 0.7061
# Fold 4 | Epoch 20 | Loss: 0.7041
# Fold 4 | Epoch 21 | Loss: 0.7021
# Fold 4 | Epoch 22 | Loss: 0.6996
# Fold 4 | Epoch 23 | Loss: 0.6978
# Fold 4 | Epoch 24 | Loss: 0.6958
# Fold 4 | Epoch 25 | Loss: 0.6937
# Fold 4 | Epoch 26 | Loss: 0.6924
# Fold 4 | Epoch 27 | Loss: 0.6910
# Fold 4 | Epoch 28 | Loss: 0.6891
# Fold 4 | Epoch 29 | Loss: 0.6875
# Fold 4 | Epoch 30 | Loss: 0.6862
# Fold 4 | Epoch 31 | Loss: 0.6843
# Fold 4 | Epoch 32 | Loss: 0.6831
# Fold 4 | Epoch 33 | Loss: 0.6817
# Fold 4 | Epoch 34 | Loss: 0.6804
# Fold 4 | Epoch 35 | Loss: 0.6792
# Fold 4 | Epoch 36 | Loss: 0.6782
# Fold 4 | Epoch 37 | Loss: 0.6771
# Fold 4 | Epoch 38 | Loss: 0.6759
# Fold 4 | Epoch 39 | Loss: 0.6748
# Fold 4 | Epoch 40 | Loss: 0.6737
# Fold 4 | Epoch 41 | Loss: 0.6726
# Fold 4 | Epoch 42 | Loss: 0.6719
# Fold 4 | Epoch 43 | Loss: 0.6706
# Fold 4 | Epoch 44 | Loss: 0.6701
# Fold 4 | Epoch 45 | Loss: 0.6690
# Fold 4 | Epoch 46 | Loss: 0.6682
# Fold 4 | Epoch 47 | Loss: 0.6671
# Fold 4 | Epoch 48 | Loss: 0.6663
# Fold 4 | Epoch 49 | Loss: 0.6656
# Fold 4 | Epoch 50 | Loss: 0.6647
# Fold 4 | Epoch 51 | Loss: 0.6637
# Fold 4 | Epoch 52 | Loss: 0.6632
# Fold 4 | Epoch 53 | Loss: 0.6626
# Fold 4 | Epoch 54 | Loss: 0.6615
# Fold 4 | Epoch 55 | Loss: 0.6609
# Fold 4 | Epoch 56 | Loss: 0.6604
# Fold 4 | Epoch 57 | Loss: 0.6593
# Fold 4 | Epoch 58 | Loss: 0.6590
# Fold 4 | Epoch 59 | Loss: 0.6581
# Fold 4 | Epoch 60 | Loss: 0.6580
# Fold 4 | Epoch 61 | Loss: 0.6572
# Fold 4 | Epoch 62 | Loss: 0.6562
# Fold 4 | Epoch 63 | Loss: 0.6559
# Fold 4 | Epoch 64 | Loss: 0.6552
# Fold 4 | Epoch 65 | Loss: 0.6546
# Fold 4 | Epoch 66 | Loss: 0.6540
# Fold 4 | Epoch 67 | Loss: 0.6534
# Fold 4 | Epoch 68 | Loss: 0.6529
# Fold 4 | Epoch 69 | Loss: 0.6520
# Fold 4 | Epoch 70 | Loss: 0.6517
# Fold 4 | Epoch 71 | Loss: 0.6513
# Fold 4 | Epoch 72 | Loss: 0.6516
# Fold 4 | Epoch 73 | Loss: 0.6510
# Fold 4 | Epoch 74 | Loss: 0.6505
# Fold 4 | Epoch 75 | Loss: 0.6500
# Fold 4 | Epoch 76 | Loss: 0.6493
# Fold 4 | Epoch 77 | Loss: 0.6487
# Fold 4 | Epoch 78 | Loss: 0.6487
# Fold 4 | Epoch 79 | Loss: 0.6476
# Fold 4 | Epoch 80 | Loss: 0.6474
# Fold 4 | Epoch 81 | Loss: 0.6471
# Fold 4 | Epoch 82 | Loss: 0.6468
# Fold 4 | Epoch 83 | Loss: 0.6462
# Fold 4 | Epoch 84 | Loss: 0.6460
# Fold 4 | Epoch 85 | Loss: 0.6456
# Fold 4 | Epoch 86 | Loss: 0.6454
# Fold 4 | Epoch 87 | Loss: 0.6445
# Fold 4 | Epoch 88 | Loss: 0.6441
# Fold 4 | Epoch 89 | Loss: 0.6441
# Fold 4 | Epoch 90 | Loss: 0.6444
# Fold 4 | Epoch 91 | Loss: 0.6434
# Fold 4 | Epoch 92 | Loss: 0.6435
# Fold 4 | Epoch 93 | Loss: 0.6430
# Fold 4 | Epoch 94 | Loss: 0.6431
# Fold 4 | Epoch 95 | Loss: 0.6417
# Fold 4 | Epoch 96 | Loss: 0.6423
# Fold 4 | Epoch 97 | Loss: 0.6413
# Fold 4 | Epoch 98 | Loss: 0.6415
# Fold 4 | Epoch 99 | Loss: 0.6413
# Fold 4 | Epoch 100 | Loss: 0.6415
# Fold 4 | Epoch 101 | Loss: 0.6408
# Fold 4 | Epoch 102 | Loss: 0.6402
# Fold 4 | Epoch 103 | Loss: 0.6401
# Fold 4 | Epoch 104 | Loss: 0.6399
# Fold 4 | Epoch 105 | Loss: 0.6396
# Fold 4 | Epoch 106 | Loss: 0.6395
# Fold 4 | Epoch 107 | Loss: 0.6391
# Fold 4 | Epoch 108 | Loss: 0.6392
# Fold 4 | Epoch 109 | Loss: 0.6389
# Fold 4 | Epoch 110 | Loss: 0.6384
# Fold 4 | Epoch 111 | Loss: 0.6379
# Fold 4 | Epoch 112 | Loss: 0.6380
# Fold 4 | Epoch 113 | Loss: 0.6376
# Fold 4 | Epoch 114 | Loss: 0.6373
# Fold 4 | Epoch 115 | Loss: 0.6372
# Fold 4 | Epoch 116 | Loss: 0.6371
# Fold 4 | Epoch 117 | Loss: 0.6364
# Fold 4 | Epoch 118 | Loss: 0.6370
# Fold 4 | Epoch 119 | Loss: 0.6366
# Fold 4 | Epoch 120 | Loss: 0.6368
# Fold 4 | Epoch 121 | Loss: 0.6361
# Fold 4 | Epoch 122 | Loss: 0.6360
# Fold 4 | Epoch 123 | Loss: 0.6357
# Fold 4 | Epoch 124 | Loss: 0.6360
# Fold 4 | Epoch 125 | Loss: 0.6347
# Fold 4 | Epoch 126 | Loss: 0.6350
# Fold 4 | Epoch 127 | Loss: 0.6348
# Fold 4 | Epoch 128 | Loss: 0.6343
# Fold 4 | Epoch 129 | Loss: 0.6349
# Fold 4 | Epoch 130 | Loss: 0.6346
# Fold 4 | Epoch 131 | Loss: 0.6336
# Fold 4 | Epoch 132 | Loss: 0.6341
# Fold 4 | Epoch 133 | Loss: 0.6337
# Fold 4 | Epoch 134 | Loss: 0.6338
# Fold 4 | Epoch 135 | Loss: 0.6340
# Fold 4 | Epoch 136 | Loss: 0.6336
# Fold 4 | Epoch 137 | Loss: 0.6337
# Fold 4 | Epoch 138 | Loss: 0.6333
# Fold 4 | Epoch 139 | Loss: 0.6332
# Fold 4 | Epoch 140 | Loss: 0.6327
# Fold 4 | Epoch 141 | Loss: 0.6329
# Fold 4 | Epoch 142 | Loss: 0.6324
# Fold 4 | Epoch 143 | Loss: 0.6329
# Fold 4 | Epoch 144 | Loss: 0.6328
# Fold 4 | Epoch 145 | Loss: 0.6326
# Fold 4 | Epoch 146 | Loss: 0.6319
# Fold 4 | Epoch 147 | Loss: 0.6319
# Fold 4 | Epoch 148 | Loss: 0.6321
# Fold 4 | Epoch 149 | Loss: 0.6320
# Fold 4 | Epoch 150 | Loss: 0.6325
# Fold 4 | Epoch 151 | Loss: 0.6317
# Fold 4 | Epoch 152 | Loss: 0.6312
# Fold 4 | Epoch 153 | Loss: 0.6311
# Fold 4 | Epoch 154 | Loss: 0.6314
# Fold 4 | Epoch 155 | Loss: 0.6308
# Fold 4 | Epoch 156 | Loss: 0.6312
# Fold 4 | Epoch 157 | Loss: 0.6306
# Fold 4 | Epoch 158 | Loss: 0.6304
# Fold 4 | Epoch 159 | Loss: 0.6301
# Fold 4 | Epoch 160 | Loss: 0.6303
# Fold 4 | Epoch 161 | Loss: 0.6304
# Fold 4 | Epoch 162 | Loss: 0.6307
# Fold 4 | Epoch 163 | Loss: 0.6303
# Fold 4 | Epoch 164 | Loss: 0.6304
# Fold 4 | Epoch 165 | Loss: 0.6299
# Fold 4 | Epoch 166 | Loss: 0.6308
# Fold 4 | Epoch 167 | Loss: 0.6297
# Fold 4 | Epoch 168 | Loss: 0.6294
# Fold 4 | Epoch 169 | Loss: 0.6291
# Fold 4 | Epoch 170 | Loss: 0.6288
# Fold 4 | Epoch 171 | Loss: 0.6295
# Fold 4 | Epoch 172 | Loss: 0.6298
# Fold 4 | Epoch 173 | Loss: 0.6295
# Fold 4 | Epoch 174 | Loss: 0.6294
# Fold 4 | Epoch 175 | Loss: 0.6289
# Fold 4 | Epoch 176 | Loss: 0.6282
# Fold 4 | Epoch 177 | Loss: 0.6285
# Fold 4 | Epoch 178 | Loss: 0.6290
# Fold 4 | Epoch 179 | Loss: 0.6283
# Fold 4 | Epoch 180 | Loss: 0.6281
# Fold 4 | Epoch 181 | Loss: 0.6286
# Fold 4 | Epoch 182 | Loss: 0.6287
# Fold 4 | Epoch 183 | Loss: 0.6284
# Fold 4 | Epoch 184 | Loss: 0.6283
# Fold 4 | Epoch 185 | Loss: 0.6282
# Fold 4 | Epoch 186 | Loss: 0.6279
# Fold 4 | Epoch 187 | Loss: 0.6281
# Fold 4 | Epoch 188 | Loss: 0.6275
# Fold 4 | Epoch 189 | Loss: 0.6273
# Fold 4 | Epoch 190 | Loss: 0.6275
# Fold 4 | Epoch 191 | Loss: 0.6273
# Fold 4 | Epoch 192 | Loss: 0.6274
# Fold 4 | Epoch 193 | Loss: 0.6273
# Fold 4 | Epoch 194 | Loss: 0.6272
# Fold 4 | Epoch 195 | Loss: 0.6271
# Fold 4 | Epoch 196 | Loss: 0.6271
# Fold 4 | Epoch 197 | Loss: 0.6271
# Fold 4 | Epoch 198 | Loss: 0.6272
# Fold 4 | Epoch 199 | Loss: 0.6268
# Fold 4 | Epoch 200 | Loss: 0.6262
# Fold 4 | Epoch 201 | Loss: 0.6264
# Fold 4 | Epoch 202 | Loss: 0.6266
# Fold 4 | Epoch 203 | Loss: 0.6261
# Fold 4 | Epoch 204 | Loss: 0.6264
# Fold 4 | Epoch 205 | Loss: 0.6273
# Fold 4 | Epoch 206 | Loss: 0.6261
# Fold 4 | Epoch 207 | Loss: 0.6266
# Fold 4 | Epoch 208 | Loss: 0.6258
# Fold 4 | Epoch 209 | Loss: 0.6262
# Fold 4 | Epoch 210 | Loss: 0.6268
# Fold 4 | Epoch 211 | Loss: 0.6253
# Fold 4 | Epoch 212 | Loss: 0.6261
# Fold 4 | Epoch 213 | Loss: 0.6253
# Fold 4 | Epoch 214 | Loss: 0.6262
# Fold 4 | Epoch 215 | Loss: 0.6259
# Fold 4 | Epoch 216 | Loss: 0.6261
# Fold 4 | Epoch 217 | Loss: 0.6263
# Fold 4 | Epoch 218 | Loss: 0.6256
# Fold 4 | Epoch 219 | Loss: 0.6253
# Fold 4 | Epoch 220 | Loss: 0.6253
# Fold 4 | Epoch 221 | Loss: 0.6258
# Fold 4 | Epoch 222 | Loss: 0.6258
# Fold 4 | Epoch 223 | Loss: 0.6257
# Fold 4 | Epoch 224 | Loss: 0.6252
# Fold 4 | Epoch 225 | Loss: 0.6245
# Fold 4 | Epoch 226 | Loss: 0.6245
# Fold 4 | Epoch 227 | Loss: 0.6249
# Fold 4 | Epoch 228 | Loss: 0.6243
# Fold 4 | Epoch 229 | Loss: 0.6252
# Fold 4 | Epoch 230 | Loss: 0.6254
# Fold 4 | Epoch 231 | Loss: 0.6248
# Fold 4 | Epoch 232 | Loss: 0.6251
# Fold 4 | Epoch 233 | Loss: 0.6248
# Fold 4 | Epoch 234 | Loss: 0.6246
# Fold 4 | Epoch 235 | Loss: 0.6248
# Fold 4 | Epoch 236 | Loss: 0.6250
# Fold 4 | Epoch 237 | Loss: 0.6244
# Fold 4 | Epoch 238 | Loss: 0.6248
# Fold 4 | Epoch 239 | Loss: 0.6248
# Fold 4 | Epoch 240 | Loss: 0.6243
# Fold 4 | Epoch 241 | Loss: 0.6238
# Fold 4 | Epoch 242 | Loss: 0.6248
# Fold 4 | Epoch 243 | Loss: 0.6242
# Fold 4 | Epoch 244 | Loss: 0.6237
# Fold 4 | Epoch 245 | Loss: 0.6242
# Fold 4 | Epoch 246 | Loss: 0.6241
# Fold 4 | Epoch 247 | Loss: 0.6242
# Fold 4 | Epoch 248 | Loss: 0.6235
# Fold 4 | Epoch 249 | Loss: 0.6242
# Fold 4 | Epoch 250 | Loss: 0.6242
# Fold 4 | Epoch 251 | Loss: 0.6244
# Fold 4 | Epoch 252 | Loss: 0.6233
# Fold 4 | Epoch 253 | Loss: 0.6236
# Fold 4 | Epoch 254 | Loss: 0.6242
# Fold 4 | Epoch 255 | Loss: 0.6244
# Fold 4 | Epoch 256 | Loss: 0.6240
# Fold 4 | Epoch 257 | Loss: 0.6236
# Fold 4 | Epoch 258 | Loss: 0.6236
# Fold 4 | Epoch 259 | Loss: 0.6232
# Fold 4 | Epoch 260 | Loss: 0.6237
# Fold 4 | Epoch 261 | Loss: 0.6232
# Fold 4 | Epoch 262 | Loss: 0.6230
# Fold 4 | Epoch 263 | Loss: 0.6240
# Fold 4 | Epoch 264 | Loss: 0.6229
# Fold 4 | Epoch 265 | Loss: 0.6229
# Fold 4 | Epoch 266 | Loss: 0.6234
# Fold 4 | Epoch 267 | Loss: 0.6230
# Fold 4 | Epoch 268 | Loss: 0.6235
# Fold 4 | Epoch 269 | Loss: 0.6228
# Fold 4 | Epoch 270 | Loss: 0.6230
# Fold 4 | Epoch 271 | Loss: 0.6239
# Fold 4 | Epoch 272 | Loss: 0.6228
# Fold 4 | Epoch 273 | Loss: 0.6234
# Fold 4 | Epoch 274 | Loss: 0.6229
# Fold 4 | Epoch 275 | Loss: 0.6228
# Fold 4 | Epoch 276 | Loss: 0.6228
# Fold 4 | Epoch 277 | Loss: 0.6225
# Fold 4 | Epoch 278 | Loss: 0.6232
# Fold 4 | Epoch 279 | Loss: 0.6229
# Fold 4 | Epoch 280 | Loss: 0.6228
# Fold 4 | Epoch 281 | Loss: 0.6225
# Fold 4 | Epoch 282 | Loss: 0.6225
# Fold 4 | Epoch 283 | Loss: 0.6227
# Fold 4 | Epoch 284 | Loss: 0.6226
# Fold 4 | Epoch 285 | Loss: 0.6226
# Fold 4 | Epoch 286 | Loss: 0.6224
# Fold 4 | Epoch 287 | Loss: 0.6222
# Fold 4 | Epoch 288 | Loss: 0.6225
# Fold 4 | Epoch 289 | Loss: 0.6224
# Fold 4 | Epoch 290 | Loss: 0.6228
# Fold 4 | Epoch 291 | Loss: 0.6216
# Fold 4 | Epoch 292 | Loss: 0.6219
# Fold 4 | Epoch 293 | Loss: 0.6214
# Fold 4 | Epoch 294 | Loss: 0.6218
# Fold 4 | Epoch 295 | Loss: 0.6217
# Fold 4 | Epoch 296 | Loss: 0.6222
# Fold 4 | Epoch 297 | Loss: 0.6225
# Fold 4 | Epoch 298 | Loss: 0.6224
# Fold 4 | Epoch 299 | Loss: 0.6219
# Fold 4 | Epoch 300 | Loss: 0.6224
#
# Starting Fold 5...
# Fold 5 | Epoch 1 | Loss: 0.8173
# Fold 5 | Epoch 2 | Loss: 0.7982
# Fold 5 | Epoch 3 | Loss: 0.7833
# Fold 5 | Epoch 4 | Loss: 0.7707
# Fold 5 | Epoch 5 | Loss: 0.7605
# Fold 5 | Epoch 6 | Loss: 0.7519
# Fold 5 | Epoch 7 | Loss: 0.7448
# Fold 5 | Epoch 8 | Loss: 0.7386
# Fold 5 | Epoch 9 | Loss: 0.7336
# Fold 5 | Epoch 10 | Loss: 0.7292
# Fold 5 | Epoch 11 | Loss: 0.7249
# Fold 5 | Epoch 12 | Loss: 0.7213
# Fold 5 | Epoch 13 | Loss: 0.7180
# Fold 5 | Epoch 14 | Loss: 0.7151
# Fold 5 | Epoch 15 | Loss: 0.7121
# Fold 5 | Epoch 16 | Loss: 0.7096
# Fold 5 | Epoch 17 | Loss: 0.7073
# Fold 5 | Epoch 18 | Loss: 0.7048
# Fold 5 | Epoch 19 | Loss: 0.7025
# Fold 5 | Epoch 20 | Loss: 0.7003
# Fold 5 | Epoch 21 | Loss: 0.6983
# Fold 5 | Epoch 22 | Loss: 0.6965
# Fold 5 | Epoch 23 | Loss: 0.6944
# Fold 5 | Epoch 24 | Loss: 0.6928
# Fold 5 | Epoch 25 | Loss: 0.6907
# Fold 5 | Epoch 26 | Loss: 0.6892
# Fold 5 | Epoch 27 | Loss: 0.6876
# Fold 5 | Epoch 28 | Loss: 0.6860
# Fold 5 | Epoch 29 | Loss: 0.6844
# Fold 5 | Epoch 30 | Loss: 0.6830
# Fold 5 | Epoch 31 | Loss: 0.6817
# Fold 5 | Epoch 32 | Loss: 0.6805
# Fold 5 | Epoch 33 | Loss: 0.6793
# Fold 5 | Epoch 34 | Loss: 0.6780
# Fold 5 | Epoch 35 | Loss: 0.6765
# Fold 5 | Epoch 36 | Loss: 0.6758
# Fold 5 | Epoch 37 | Loss: 0.6748
# Fold 5 | Epoch 38 | Loss: 0.6733
# Fold 5 | Epoch 39 | Loss: 0.6723
# Fold 5 | Epoch 40 | Loss: 0.6714
# Fold 5 | Epoch 41 | Loss: 0.6702
# Fold 5 | Epoch 42 | Loss: 0.6695
# Fold 5 | Epoch 43 | Loss: 0.6684
# Fold 5 | Epoch 44 | Loss: 0.6677
# Fold 5 | Epoch 45 | Loss: 0.6670
# Fold 5 | Epoch 46 | Loss: 0.6659
# Fold 5 | Epoch 47 | Loss: 0.6650
# Fold 5 | Epoch 48 | Loss: 0.6640
# Fold 5 | Epoch 49 | Loss: 0.6629
# Fold 5 | Epoch 50 | Loss: 0.6619
# Fold 5 | Epoch 51 | Loss: 0.6621
# Fold 5 | Epoch 52 | Loss: 0.6614
# Fold 5 | Epoch 53 | Loss: 0.6603
# Fold 5 | Epoch 54 | Loss: 0.6596
# Fold 5 | Epoch 55 | Loss: 0.6588
# Fold 5 | Epoch 56 | Loss: 0.6584
# Fold 5 | Epoch 57 | Loss: 0.6575
# Fold 5 | Epoch 58 | Loss: 0.6572
# Fold 5 | Epoch 59 | Loss: 0.6559
# Fold 5 | Epoch 60 | Loss: 0.6551
# Fold 5 | Epoch 61 | Loss: 0.6552
# Fold 5 | Epoch 62 | Loss: 0.6546
# Fold 5 | Epoch 63 | Loss: 0.6539
# Fold 5 | Epoch 64 | Loss: 0.6534
# Fold 5 | Epoch 65 | Loss: 0.6529
# Fold 5 | Epoch 66 | Loss: 0.6520
# Fold 5 | Epoch 67 | Loss: 0.6512
# Fold 5 | Epoch 68 | Loss: 0.6513
# Fold 5 | Epoch 69 | Loss: 0.6513
# Fold 5 | Epoch 70 | Loss: 0.6503
# Fold 5 | Epoch 71 | Loss: 0.6502
# Fold 5 | Epoch 72 | Loss: 0.6489
# Fold 5 | Epoch 73 | Loss: 0.6486
# Fold 5 | Epoch 74 | Loss: 0.6479
# Fold 5 | Epoch 75 | Loss: 0.6480
# Fold 5 | Epoch 76 | Loss: 0.6475
# Fold 5 | Epoch 77 | Loss: 0.6475
# Fold 5 | Epoch 78 | Loss: 0.6465
# Fold 5 | Epoch 79 | Loss: 0.6467
# Fold 5 | Epoch 80 | Loss: 0.6456
# Fold 5 | Epoch 81 | Loss: 0.6459
# Fold 5 | Epoch 82 | Loss: 0.6453
# Fold 5 | Epoch 83 | Loss: 0.6448
# Fold 5 | Epoch 84 | Loss: 0.6445
# Fold 5 | Epoch 85 | Loss: 0.6446
# Fold 5 | Epoch 86 | Loss: 0.6442
# Fold 5 | Epoch 87 | Loss: 0.6433
# Fold 5 | Epoch 88 | Loss: 0.6434
# Fold 5 | Epoch 89 | Loss: 0.6428
# Fold 5 | Epoch 90 | Loss: 0.6426
# Fold 5 | Epoch 91 | Loss: 0.6421
# Fold 5 | Epoch 92 | Loss: 0.6422
# Fold 5 | Epoch 93 | Loss: 0.6423
# Fold 5 | Epoch 94 | Loss: 0.6411
# Fold 5 | Epoch 95 | Loss: 0.6416
# Fold 5 | Epoch 96 | Loss: 0.6411
# Fold 5 | Epoch 97 | Loss: 0.6402
# Fold 5 | Epoch 98 | Loss: 0.6400
# Fold 5 | Epoch 99 | Loss: 0.6398
# Fold 5 | Epoch 100 | Loss: 0.6402
# Fold 5 | Epoch 101 | Loss: 0.6393
# Fold 5 | Epoch 102 | Loss: 0.6397
# Fold 5 | Epoch 103 | Loss: 0.6387
# Fold 5 | Epoch 104 | Loss: 0.6392
# Fold 5 | Epoch 105 | Loss: 0.6383
# Fold 5 | Epoch 106 | Loss: 0.6383
# Fold 5 | Epoch 107 | Loss: 0.6380
# Fold 5 | Epoch 108 | Loss: 0.6383
# Fold 5 | Epoch 109 | Loss: 0.6371
# Fold 5 | Epoch 110 | Loss: 0.6369
# Fold 5 | Epoch 111 | Loss: 0.6370
# Fold 5 | Epoch 112 | Loss: 0.6377
# Fold 5 | Epoch 113 | Loss: 0.6368
# Fold 5 | Epoch 114 | Loss: 0.6364
# Fold 5 | Epoch 115 | Loss: 0.6363
# Fold 5 | Epoch 116 | Loss: 0.6364
# Fold 5 | Epoch 117 | Loss: 0.6368
# Fold 5 | Epoch 118 | Loss: 0.6359
# Fold 5 | Epoch 119 | Loss: 0.6358
# Fold 5 | Epoch 120 | Loss: 0.6354
# Fold 5 | Epoch 121 | Loss: 0.6356
# Fold 5 | Epoch 122 | Loss: 0.6349
# Fold 5 | Epoch 123 | Loss: 0.6352
# Fold 5 | Epoch 124 | Loss: 0.6344
# Fold 5 | Epoch 125 | Loss: 0.6351
# Fold 5 | Epoch 126 | Loss: 0.6351
# Fold 5 | Epoch 127 | Loss: 0.6341
# Fold 5 | Epoch 128 | Loss: 0.6345
# Fold 5 | Epoch 129 | Loss: 0.6342
# Fold 5 | Epoch 130 | Loss: 0.6337
# Fold 5 | Epoch 131 | Loss: 0.6337
# Fold 5 | Epoch 132 | Loss: 0.6332
# Fold 5 | Epoch 133 | Loss: 0.6332
# Fold 5 | Epoch 134 | Loss: 0.6333
# Fold 5 | Epoch 135 | Loss: 0.6333
# Fold 5 | Epoch 136 | Loss: 0.6329
# Fold 5 | Epoch 137 | Loss: 0.6326
# Fold 5 | Epoch 138 | Loss: 0.6326
# Fold 5 | Epoch 139 | Loss: 0.6329
# Fold 5 | Epoch 140 | Loss: 0.6325
# Fold 5 | Epoch 141 | Loss: 0.6326
# Fold 5 | Epoch 142 | Loss: 0.6323
# Fold 5 | Epoch 143 | Loss: 0.6325
# Fold 5 | Epoch 144 | Loss: 0.6318
# Fold 5 | Epoch 145 | Loss: 0.6318
# Fold 5 | Epoch 146 | Loss: 0.6324
# Fold 5 | Epoch 147 | Loss: 0.6318
# Fold 5 | Epoch 148 | Loss: 0.6316
# Fold 5 | Epoch 149 | Loss: 0.6314
# Fold 5 | Epoch 150 | Loss: 0.6310
# Fold 5 | Epoch 151 | Loss: 0.6307
# Fold 5 | Epoch 152 | Loss: 0.6308
# Fold 5 | Epoch 153 | Loss: 0.6312
# Fold 5 | Epoch 154 | Loss: 0.6316
# Fold 5 | Epoch 155 | Loss: 0.6309
# Fold 5 | Epoch 156 | Loss: 0.6310
# Fold 5 | Epoch 157 | Loss: 0.6306
# Fold 5 | Epoch 158 | Loss: 0.6301
# Fold 5 | Epoch 159 | Loss: 0.6306
# Fold 5 | Epoch 160 | Loss: 0.6305
# Fold 5 | Epoch 161 | Loss: 0.6302
# Fold 5 | Epoch 162 | Loss: 0.6303
# Fold 5 | Epoch 163 | Loss: 0.6302
# Fold 5 | Epoch 164 | Loss: 0.6300
# Fold 5 | Epoch 165 | Loss: 0.6299
# Fold 5 | Epoch 166 | Loss: 0.6296
# Fold 5 | Epoch 167 | Loss: 0.6295
# Fold 5 | Epoch 168 | Loss: 0.6289
# Fold 5 | Epoch 169 | Loss: 0.6291
# Fold 5 | Epoch 170 | Loss: 0.6300
# Fold 5 | Epoch 171 | Loss: 0.6292
# Fold 5 | Epoch 172 | Loss: 0.6290
# Fold 5 | Epoch 173 | Loss: 0.6294
# Fold 5 | Epoch 174 | Loss: 0.6290
# Fold 5 | Epoch 175 | Loss: 0.6296
# Fold 5 | Epoch 176 | Loss: 0.6278
# Fold 5 | Epoch 177 | Loss: 0.6282
# Fold 5 | Epoch 178 | Loss: 0.6288
# Fold 5 | Epoch 179 | Loss: 0.6289
# Fold 5 | Epoch 180 | Loss: 0.6284
# Fold 5 | Epoch 181 | Loss: 0.6283
# Fold 5 | Epoch 182 | Loss: 0.6289
# Fold 5 | Epoch 183 | Loss: 0.6280
# Fold 5 | Epoch 184 | Loss: 0.6284
# Fold 5 | Epoch 185 | Loss: 0.6279
# Fold 5 | Epoch 186 | Loss: 0.6276
# Fold 5 | Epoch 187 | Loss: 0.6284
# Fold 5 | Epoch 188 | Loss: 0.6274
# Fold 5 | Epoch 189 | Loss: 0.6278
# Fold 5 | Epoch 190 | Loss: 0.6281
# Fold 5 | Epoch 191 | Loss: 0.6277
# Fold 5 | Epoch 192 | Loss: 0.6276
# Fold 5 | Epoch 193 | Loss: 0.6274
# Fold 5 | Epoch 194 | Loss: 0.6276
# Fold 5 | Epoch 195 | Loss: 0.6270
# Fold 5 | Epoch 196 | Loss: 0.6281
# Fold 5 | Epoch 197 | Loss: 0.6278
# Fold 5 | Epoch 198 | Loss: 0.6270
# Fold 5 | Epoch 199 | Loss: 0.6268
# Fold 5 | Epoch 200 | Loss: 0.6271
# Fold 5 | Epoch 201 | Loss: 0.6271
# Fold 5 | Epoch 202 | Loss: 0.6261
# Fold 5 | Epoch 203 | Loss: 0.6265
# Fold 5 | Epoch 204 | Loss: 0.6265
# Fold 5 | Epoch 205 | Loss: 0.6266
# Fold 5 | Epoch 206 | Loss: 0.6269
# Fold 5 | Epoch 207 | Loss: 0.6258
# Fold 5 | Epoch 208 | Loss: 0.6261
# Fold 5 | Epoch 209 | Loss: 0.6265
# Fold 5 | Epoch 210 | Loss: 0.6256
# Fold 5 | Epoch 211 | Loss: 0.6261
# Fold 5 | Epoch 212 | Loss: 0.6262
# Fold 5 | Epoch 213 | Loss: 0.6261
# Fold 5 | Epoch 214 | Loss: 0.6264
# Fold 5 | Epoch 215 | Loss: 0.6265
# Fold 5 | Epoch 216 | Loss: 0.6256
# Fold 5 | Epoch 217 | Loss: 0.6266
# Fold 5 | Epoch 218 | Loss: 0.6255
# Fold 5 | Epoch 219 | Loss: 0.6259
# Fold 5 | Epoch 220 | Loss: 0.6259
# Fold 5 | Epoch 221 | Loss: 0.6255
# Fold 5 | Epoch 222 | Loss: 0.6261
# Fold 5 | Epoch 223 | Loss: 0.6261
# Fold 5 | Epoch 224 | Loss: 0.6252
# Fold 5 | Epoch 225 | Loss: 0.6249
# Fold 5 | Epoch 226 | Loss: 0.6255
# Fold 5 | Epoch 227 | Loss: 0.6260
# Fold 5 | Epoch 228 | Loss: 0.6250
# Fold 5 | Epoch 229 | Loss: 0.6251
# Fold 5 | Epoch 230 | Loss: 0.6249
# Fold 5 | Epoch 231 | Loss: 0.6250
# Fold 5 | Epoch 232 | Loss: 0.6256
# Fold 5 | Epoch 233 | Loss: 0.6248
# Fold 5 | Epoch 234 | Loss: 0.6255
# Fold 5 | Epoch 235 | Loss: 0.6240
# Fold 5 | Epoch 236 | Loss: 0.6244
# Fold 5 | Epoch 237 | Loss: 0.6248
# Fold 5 | Epoch 238 | Loss: 0.6244
# Fold 5 | Epoch 239 | Loss: 0.6252
# Fold 5 | Epoch 240 | Loss: 0.6247
# Fold 5 | Epoch 241 | Loss: 0.6253
# Fold 5 | Epoch 242 | Loss: 0.6251
# Fold 5 | Epoch 243 | Loss: 0.6246
# Fold 5 | Epoch 244 | Loss: 0.6243
# Fold 5 | Epoch 245 | Loss: 0.6247
# Fold 5 | Epoch 246 | Loss: 0.6248
# Fold 5 | Epoch 247 | Loss: 0.6243
# Fold 5 | Epoch 248 | Loss: 0.6242
# Fold 5 | Epoch 249 | Loss: 0.6244
# Fold 5 | Epoch 250 | Loss: 0.6239
# Fold 5 | Epoch 251 | Loss: 0.6241
# Fold 5 | Epoch 252 | Loss: 0.6240
# Fold 5 | Epoch 253 | Loss: 0.6243
# Fold 5 | Epoch 254 | Loss: 0.6244
# Fold 5 | Epoch 255 | Loss: 0.6241
# Fold 5 | Epoch 256 | Loss: 0.6239
# Fold 5 | Epoch 257 | Loss: 0.6249
# Fold 5 | Epoch 258 | Loss: 0.6238
# Fold 5 | Epoch 259 | Loss: 0.6230
# Fold 5 | Epoch 260 | Loss: 0.6235
# Fold 5 | Epoch 261 | Loss: 0.6238
# Fold 5 | Epoch 262 | Loss: 0.6237
# Fold 5 | Epoch 263 | Loss: 0.6237
# Fold 5 | Epoch 264 | Loss: 0.6238
# Fold 5 | Epoch 265 | Loss: 0.6246
# Fold 5 | Epoch 266 | Loss: 0.6231
# Fold 5 | Epoch 267 | Loss: 0.6240
# Fold 5 | Epoch 268 | Loss: 0.6236
# Fold 5 | Epoch 269 | Loss: 0.6234
# Fold 5 | Epoch 270 | Loss: 0.6233
# Fold 5 | Epoch 271 | Loss: 0.6239
# Fold 5 | Epoch 272 | Loss: 0.6232
# Fold 5 | Epoch 273 | Loss: 0.6233
# Fold 5 | Epoch 274 | Loss: 0.6240
# Fold 5 | Epoch 275 | Loss: 0.6231
# Fold 5 | Epoch 276 | Loss: 0.6235
# Fold 5 | Epoch 277 | Loss: 0.6232
# Fold 5 | Epoch 278 | Loss: 0.6230
# Fold 5 | Epoch 279 | Loss: 0.6225
# Fold 5 | Epoch 280 | Loss: 0.6226
# Fold 5 | Epoch 281 | Loss: 0.6231
# Fold 5 | Epoch 282 | Loss: 0.6223
# Fold 5 | Epoch 283 | Loss: 0.6224
# Fold 5 | Epoch 284 | Loss: 0.6233
# Fold 5 | Epoch 285 | Loss: 0.6233
# Fold 5 | Epoch 286 | Loss: 0.6227
# Fold 5 | Epoch 287 | Loss: 0.6232
# Fold 5 | Epoch 288 | Loss: 0.6230
# Fold 5 | Epoch 289 | Loss: 0.6232
# Fold 5 | Epoch 290 | Loss: 0.6225
# Fold 5 | Epoch 291 | Loss: 0.6222
# Fold 5 | Epoch 292 | Loss: 0.6221
# Fold 5 | Epoch 293 | Loss: 0.6228
# Fold 5 | Epoch 294 | Loss: 0.6225
# Fold 5 | Epoch 295 | Loss: 0.6223
# Fold 5 | Epoch 296 | Loss: 0.6227
# Fold 5 | Epoch 297 | Loss: 0.6237
# Fold 5 | Epoch 298 | Loss: 0.6221
# Fold 5 | Epoch 299 | Loss: 0.6220
# Fold 5 | Epoch 300 | Loss: 0.6223
#
# Final Results after Cross-Validation:
# Average MRR: 0.1359, Average Hit@1: 0.0776, Average Hit@3: 0.1592, Average Hit@10: 0.2940
